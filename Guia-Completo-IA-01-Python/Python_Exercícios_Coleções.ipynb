# %% [markdown]
# <a href="https://colab.research.google.com/github/DataScience-2021/Guia-Completo-IA-01-Python/blob/main/Python_Exerc%C3%ADcios_Cole%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício 1 - listas
#
# Crie uma estrutura de repetição para fazer a leitura de 5 números inteiros e os armazene dentro de uma lista. Após a leitura, crie outra estrutura de repetição para somar todos os valores digitados

# %%
lista = []
for _ in range(1, 6):
  valor = int(input('Digite o valor: '))
  lista.append(valor)
# Out:
# Digite o valor: 1
# Digite o valor: 2
# Digite o valor: 3
# Digite o valor: 4
# Digite o valor: 5

# %%
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
len(lista)
# Out:
# 5

# %%
soma = 0
for i in range(len(lista)):
  #print(lista[i])
  soma += lista[i]
print('Soma: ', soma)
# Out:
# Soma:  15

# %%
lista.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-8aeca298dcba> in <module>()
# ----> 1 lista.sum()
#
# AttributeError: 'list' object has no attribute 'sum'

# %%
import numpy as np
np.array(lista).sum()
# Out:
# 15

# %% [markdown]
# # Exercícios 2 - dicionários
#
# Crie um dicionário para armazenar o nome e a nota de 3 alunos, fazendo a leitura dos valores por meio de uma estrutura de repetição. Depois, crie uma nova estrutura de repetição para somar todas as notas e retornar a média

# %%
alunos = {}
for _ in range(1, 4):
  nome = input('Digite o nome: ')
  nota = float(input('Digite a nota: '))
  alunos[nome] = nota
# Out:
# Digite o nome: pedro
# Digite a nota: 7
# Digite o nome: joao
# Digite a nota: 8
# Digite o nome: maria
# Digite a nota: 10

# %%
alunos
# Out:
# {'joao': 8.0, 'maria': 10.0, 'pedro': 7.0}

# %%
alunos['maria']
# Out:
# 10.0

# %%
alunos.values()
# Out:
# dict_values([7.0, 8.0, 10.0])

# %%
soma = 0
for nota in alunos.values():
  #print(nota)
  soma += nota
print('Média: ', soma / 3)
# Out:
# Média:  8.333333333333334

# %% [markdown]
# # Exercício 3: Matriz
#
# Dada a matriz abaixo, construa uma estrutura de repetição para percorrer e somar todos os elementos da matriz

# %%
matriz = np.array([[3, 4, 1],
                   [3, 1, 5]])
matriz
# Out:
# array([[3, 4, 1],
#        [3, 1, 5]])

# %%
matriz.shape
# Out:
# (2, 3)

# %%
soma = 0
for i in range(matriz.shape[0]):
  for j in range(matriz.shape[1]):
    #print(matriz[i][j])
    soma += matriz[i][j]
print('Soma: ', soma)
# Out:
# Soma:  17
