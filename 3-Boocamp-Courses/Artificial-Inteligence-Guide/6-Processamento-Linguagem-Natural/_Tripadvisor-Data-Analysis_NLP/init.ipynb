# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: wordcloud==1.8.1 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from -r ./requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: autoviml in /home/biolabs/anaconda3/lib/python3.8/site-packages (from -r ./requirements.txt (line 2)) (0.1.683)
# Requirement already satisfied: gensim==3.8.3 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from -r ./requirements.txt (line 3)) (3.8.3)
# Requirement already satisfied: transformers==4.5.1 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from -r ./requirements.txt (line 4)) (4.5.1)
# Requirement already satisfied: sentencepiece in /home/biolabs/anaconda3/lib/python3.8/site-packages (from -r ./requirements.txt (line 5)) (0.1.96)
# Requirement already satisfied: vaderSentiment in /home/biolabs/anaconda3/lib/python3.8/site-packages (from -r ./requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: pydot in /home/biolabs/anaconda3/lib/python3.8/site-packages (from -r ./requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: pillow in /home/biolabs/anaconda3/lib/python3.8/site-packages (from wordcloud==1.8.1->-r ./requirements.txt (line 1)) (8.4.0)
# Requirement already satisfied: numpy>=1.6.1 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from wordcloud==1.8.1->-r ./requirements.txt (line 1)) (1.21.2)
# Requirement already satisfied: matplotlib in /home/biolabs/anaconda3/lib/python3.8/site-packages (from wordcloud==1.8.1->-r ./requirements.txt (line 1)) (3.4.3)
# Requirement already satisfied: scipy>=0.18.1 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from gensim==3.8.3->-r ./requirements.txt (line 3)) (1.7.1)
# Requirement already satisfied: six>=1.5.0 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from gensim==3.8.3->-r ./requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: smart-open>=1.8.1 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from gensim==3.8.3->-r ./requirements.txt (line 3)) (5.2.1)
# Requirement already satisfied: requests in /home/biolabs/anaconda3/lib/python3.8/site-packages (from transformers==4.5.1->-r ./requirements.txt (line 4)) (2.26.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from transformers==4.5.1->-r ./requirements.txt (line 4)) (2021.8.3)
# Requirement already satisfied: packaging in /home/biolabs/.local/lib/python3.8/site-packages (from transformers==4.5.1->-r ./requirements.txt (line 4)) (21.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from transformers==4.5.1->-r ./requirements.txt (line 4)) (0.10.3)
# Requirement already satisfied: sacremoses in /home/biolabs/anaconda3/lib/python3.8/site-packages (from transformers==4.5.1->-r ./requirements.txt (line 4)) (0.0.46)
# Requirement already satisfied: tqdm>=4.27 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from transformers==4.5.1->-r ./requirements.txt (line 4)) (4.62.2)
# Requirement already satisfied: filelock in /home/biolabs/anaconda3/lib/python3.8/site-packages (from transformers==4.5.1->-r ./requirements.txt (line 4)) (3.0.12)
# Requirement already satisfied: ipython in /home/biolabs/.local/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (7.28.0)
# Requirement already satisfied: jupyter in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: beautifulsoup4 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (4.10.0)
# Requirement already satisfied: scikit-learn>=0.23.1 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (0.24.2)
# Requirement already satisfied: xgboost>=1.1.1 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: shap>=0.36.0 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (0.40.0)
# Requirement already satisfied: textblob in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (0.17.1)
# Requirement already satisfied: seaborn in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (0.11.2)
# Requirement already satisfied: nltk in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (3.6.5)
# Requirement already satisfied: emoji in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (1.6.1)
# Requirement already satisfied: catboost in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: xlrd in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: pandas in /home/biolabs/.local/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (1.3.4)
# Requirement already satisfied: imbalanced-learn>=0.7 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from autoviml->-r ./requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /home/biolabs/.local/lib/python3.8/site-packages (from pydot->-r ./requirements.txt (line 7)) (2.4.7)
# Requirement already satisfied: joblib>=0.11 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from imbalanced-learn>=0.7->autoviml->-r ./requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.23.1->autoviml->-r ./requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: numba in /home/biolabs/anaconda3/lib/python3.8/site-packages (from shap>=0.36.0->autoviml->-r ./requirements.txt (line 2)) (0.53.1)
# Requirement already satisfied: slicer==0.0.7 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from shap>=0.36.0->autoviml->-r ./requirements.txt (line 2)) (0.0.7)
# Requirement already satisfied: cloudpickle in /home/biolabs/anaconda3/lib/python3.8/site-packages (from shap>=0.36.0->autoviml->-r ./requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->autoviml->-r ./requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: graphviz in /home/biolabs/anaconda3/lib/python3.8/site-packages (from catboost->autoviml->-r ./requirements.txt (line 2)) (0.17)
# Requirement already satisfied: plotly in /home/biolabs/anaconda3/lib/python3.8/site-packages (from catboost->autoviml->-r ./requirements.txt (line 2)) (5.3.1)
# Requirement already satisfied: pytz>=2017.3 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from pandas->autoviml->-r ./requirements.txt (line 2)) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from pandas->autoviml->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: setuptools>=18.5 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from ipython->autoviml->-r ./requirements.txt (line 2)) (58.0.4)
# Requirement already satisfied: backcall in /home/biolabs/.local/lib/python3.8/site-packages (from ipython->autoviml->-r ./requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from ipython->autoviml->-r ./requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /home/biolabs/.local/lib/python3.8/site-packages (from ipython->autoviml->-r ./requirements.txt (line 2)) (0.1.3)
# Requirement already satisfied: pygments in /home/biolabs/anaconda3/lib/python3.8/site-packages (from ipython->autoviml->-r ./requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: decorator in /home/biolabs/.local/lib/python3.8/site-packages (from ipython->autoviml->-r ./requirements.txt (line 2)) (5.1.0)
# Requirement already satisfied: pickleshare in /home/biolabs/.local/lib/python3.8/site-packages (from ipython->autoviml->-r ./requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /home/biolabs/.local/lib/python3.8/site-packages (from ipython->autoviml->-r ./requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: traitlets>=4.2 in /home/biolabs/.local/lib/python3.8/site-packages (from ipython->autoviml->-r ./requirements.txt (line 2)) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/biolabs/.local/lib/python3.8/site-packages (from ipython->autoviml->-r ./requirements.txt (line 2)) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/biolabs/.local/lib/python3.8/site-packages (from jedi>=0.16->ipython->autoviml->-r ./requirements.txt (line 2)) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/biolabs/.local/lib/python3.8/site-packages (from pexpect>4.3->ipython->autoviml->-r ./requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/biolabs/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviml->-r ./requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: notebook in /home/biolabs/.local/lib/python3.8/site-packages (from jupyter->autoviml->-r ./requirements.txt (line 2)) (6.4.5)
# Requirement already satisfied: ipywidgets in /home/biolabs/.local/lib/python3.8/site-packages (from jupyter->autoviml->-r ./requirements.txt (line 2)) (7.6.5)
# Requirement already satisfied: nbconvert in /home/biolabs/.local/lib/python3.8/site-packages (from jupyter->autoviml->-r ./requirements.txt (line 2)) (6.2.0)
# Requirement already satisfied: jupyter-console in /home/biolabs/anaconda3/lib/python3.8/site-packages (from jupyter->autoviml->-r ./requirements.txt (line 2)) (6.4.0)
# Requirement already satisfied: qtconsole in /home/biolabs/anaconda3/lib/python3.8/site-packages (from jupyter->autoviml->-r ./requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: ipykernel in /home/biolabs/.local/lib/python3.8/site-packages (from jupyter->autoviml->-r ./requirements.txt (line 2)) (6.4.1)
# Requirement already satisfied: ipython-genutils in /home/biolabs/.local/lib/python3.8/site-packages (from ipykernel->jupyter->autoviml->-r ./requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/biolabs/.local/lib/python3.8/site-packages (from ipykernel->jupyter->autoviml->-r ./requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: jupyter-client<8.0 in /home/biolabs/.local/lib/python3.8/site-packages (from ipykernel->jupyter->autoviml->-r ./requirements.txt (line 2)) (7.0.6)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/biolabs/.local/lib/python3.8/site-packages (from ipykernel->jupyter->autoviml->-r ./requirements.txt (line 2)) (6.1)
# Requirement already satisfied: pyzmq>=13 in /home/biolabs/.local/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviml->-r ./requirements.txt (line 2)) (22.3.0)
# Requirement already satisfied: entrypoints in /home/biolabs/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviml->-r ./requirements.txt (line 2)) (0.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/biolabs/.local/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviml->-r ./requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/biolabs/.local/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviml->-r ./requirements.txt (line 2)) (4.8.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/biolabs/.local/lib/python3.8/site-packages (from ipywidgets->jupyter->autoviml->-r ./requirements.txt (line 2)) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/biolabs/.local/lib/python3.8/site-packages (from ipywidgets->jupyter->autoviml->-r ./requirements.txt (line 2)) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/biolabs/.local/lib/python3.8/site-packages (from ipywidgets->jupyter->autoviml->-r ./requirements.txt (line 2)) (3.5.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviml->-r ./requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviml->-r ./requirements.txt (line 2)) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviml->-r ./requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: argon2-cffi in /home/biolabs/.local/lib/python3.8/site-packages (from notebook->jupyter->autoviml->-r ./requirements.txt (line 2)) (21.1.0)
# Requirement already satisfied: jinja2 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from notebook->jupyter->autoviml->-r ./requirements.txt (line 2)) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /home/biolabs/.local/lib/python3.8/site-packages (from notebook->jupyter->autoviml->-r ./requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/biolabs/.local/lib/python3.8/site-packages (from notebook->jupyter->autoviml->-r ./requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: prometheus-client in /home/biolabs/.local/lib/python3.8/site-packages (from notebook->jupyter->autoviml->-r ./requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/biolabs/.local/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter->autoviml->-r ./requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: pycparser in /home/biolabs/.local/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->autoviml->-r ./requirements.txt (line 2)) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from jinja2->notebook->jupyter->autoviml->-r ./requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from matplotlib->wordcloud==1.8.1->-r ./requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from matplotlib->wordcloud==1.8.1->-r ./requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/biolabs/.local/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml->-r ./requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /home/biolabs/.local/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml->-r ./requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: testpath in /home/biolabs/.local/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml->-r ./requirements.txt (line 2)) (0.5.0)
# Requirement already satisfied: defusedxml in /home/biolabs/.local/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml->-r ./requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/biolabs/.local/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml->-r ./requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/biolabs/.local/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml->-r ./requirements.txt (line 2)) (0.5.4)
# Requirement already satisfied: bleach in /home/biolabs/.local/lib/python3.8/site-packages (from nbconvert->jupyter->autoviml->-r ./requirements.txt (line 2)) (4.1.0)
# Requirement already satisfied: webencodings in /home/biolabs/.local/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->autoviml->-r ./requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: click in /home/biolabs/anaconda3/lib/python3.8/site-packages (from nltk->autoviml->-r ./requirements.txt (line 2)) (7.1.2)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from numba->shap>=0.36.0->autoviml->-r ./requirements.txt (line 2)) (0.36.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from plotly->catboost->autoviml->-r ./requirements.txt (line 2)) (8.0.1)
# Requirement already satisfied: qtpy in /home/biolabs/anaconda3/lib/python3.8/site-packages (from qtconsole->jupyter->autoviml->-r ./requirements.txt (line 2)) (1.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from requests->transformers==4.5.1->-r ./requirements.txt (line 4)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from requests->transformers==4.5.1->-r ./requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from requests->transformers==4.5.1->-r ./requirements.txt (line 4)) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/biolabs/anaconda3/lib/python3.8/site-packages (from requests->transformers==4.5.1->-r ./requirements.txt (line 4)) (2.10)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ecb6ef89-a5cc-4fd9-84f0-ebed68e64f13' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
