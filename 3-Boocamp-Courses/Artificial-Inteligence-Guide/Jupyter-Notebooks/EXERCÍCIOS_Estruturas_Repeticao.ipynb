# %%
print('Ler 5 notas e informar a média')
numero=0
soma = 0
for _ in range(1,6):
  numero = float(input('Entre com a nota '))
  soma = soma + numero
media = soma / 5
print('O valor total da soma é ', soma)
print('O valor total da média é ', media)
# Out:
# Ler 5 notas e informar a média
# Entre com a nota 1
# Entre com a nota 2
# Entre com a nota 3
# Entre com a nota 4
# Entre com a nota 5
# O valor total da soma é  15.0
# O valor total da média é  3.0

# %%
print('Imprimir a tabuada do número 3 (3 x 1 = 1 - 3 x 10 = 30)')
numero=1
for i in range(1,11):
  produto = 3 * numero
  print(f'3x',numero,'=',produto)
  numero=numero+1
# Out:
# Imprimir a tabuada do número 3 (3 x 1 = 1 - 3 x 10 = 30)
# 3x 1 = 3
# 3x 2 = 6
# 3x 3 = 9
# 3x 4 = 12
# 3x 5 = 15
# 3x 6 = 18
# 3x 7 = 21
# 3x 8 = 24
# 3x 9 = 27
# 3x 10 = 30

# %%
for i in range(1,11):
  print('3 x {} = {}'.format(i, 3*i))
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
