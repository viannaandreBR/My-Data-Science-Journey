# %% [markdown]
# # Distribuição de frequência

# %% [markdown]
# ## Importação das bibliotecas e dados originais

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dados = np.array([160, 165, 167, 164, 160, 166, 160, 161, 150, 152, 173, 160, 155,
                  164, 168, 162, 161, 168, 163, 156, 155, 169, 151, 170, 164,
                  155, 152, 163, 160, 155, 157, 156, 158, 158, 161, 154, 161, 156, 172, 153])

# %%
dados.shape
# Out:
# (40,)

# %% [markdown]
# ## Ordenação

# %%
dados = np.sort(dados)

# %%
dados
# Out:
# array([150, 151, 152, 152, 153, 154, 155, 155, 155, 155, 156, 156, 156,
#        157, 158, 158, 160, 160, 160, 160, 160, 161, 161, 161, 161, 162,
#        163, 163, 164, 164, 164, 165, 166, 167, 168, 168, 169, 170, 172,
#        173])

# %%
minimo = dados.min()
minimo
# Out:
# 150

# %%
maximo = dados.max()
maximo
# Out:
# 173

# %%
np.unique(dados, return_counts=True)
# Out:
# (array([150, 151, 152, 153, 154, 155, 156, 157, 158, 160, 161, 162, 163,
#         164, 165, 166, 167, 168, 169, 170, 172, 173]),
#  array([1, 1, 2, 1, 1, 4, 3, 1, 2, 5, 4, 1, 2, 3, 1, 1, 1, 2, 1, 1, 1, 1]))

# %%
#np.unique(dados, return_counts=True)
np.unique(dados, return_counts=False)
# Out:
# array([150, 151, 152, 153, 154, 155, 156, 157, 158, 160, 161, 162, 163,
#        164, 165, 166, 167, 168, 169, 170, 172, 173])

# %%
plt.bar(dados, dados)
# Out:
# <BarContainer object of 40 artists>

# %% [markdown]
# ## Número de classes
#
# - i = 1 + 3.3 log n

# %%
n = len(dados)
n
# Out:
# 40

# %%
i = 1 + 3.3 * np.log10(n)
i
# Out:
# 6.286797971382276

# %%
i = round(i)
i
# Out:
# 6

# %% [markdown]
# ## Amplitude do intervalo
#
# - h = AA / i
# - AA = Xmax - Xmin

# %%
AA = maximo - minimo
AA
# Out:
# 23

# %%
h = AA / i
h
# Out:
# 3.8333333333333335

# %%
import math
h = math.ceil(h)
h
# Out:
# 4

# %% [markdown]
# ## Construção da distribuição de frequência

# %%
intervalos = np.arange(minimo, maximo + 2, step = h)
intervalos
# Out:
# array([150, 154, 158, 162, 166, 170, 174])

# %%
intervalo1, intervalo2, intervalo3, intervalo4, intervalo5, intervalo6 = 0,0,0,0,0,0
for i in range(n):
  if dados[i] >= intervalos[0] and dados[i] < intervalos[1]:
    intervalo1 += 1
  elif dados[i] >= intervalos[1] and dados[i] < intervalos[2]:
    intervalo2 += 1
  elif dados[i] >= intervalos[2] and dados[i] < intervalos[3]:
    intervalo3 += 1
  elif dados[i] >= intervalos[3] and dados[i] < intervalos[4]:
    intervalo4 += 1
  elif dados[i] >= intervalos[4] and dados[i] < intervalos[5]:
    intervalo5 += 1
  elif dados[i] >= intervalos[5] and dados[i] < intervalos[6]:
    intervalo6 += 1

# %%
lista_intervalos = []
lista_intervalos.append(intervalo1)
lista_intervalos.append(intervalo2)
lista_intervalos.append(intervalo3)
lista_intervalos.append(intervalo4)
lista_intervalos.append(intervalo5)
lista_intervalos.append(intervalo6)
lista_intervalos
# Out:
# [5, 9, 11, 7, 5, 3]

# %%
lista_classes = []
for i in range(len(lista_intervalos)):
  lista_classes.append(str(intervalos[i]) + '-' + str(intervalos[i + 1]))

# %%
lista_classes
# Out:
# ['150-154', '154-158', '158-162', '162-166', '166-170', '170-174']

# %%
plt.bar(lista_classes, lista_intervalos)
plt.title('Distribuição de frequência - histograma')
plt.xlabel('intervalos')
plt.ylabel('valores');

# %% [markdown]
# ## Distribuição de frequência e histograma com numpy e matplotlib
#
# - https://numpy.org/doc/stable/reference/generated/numpy.histogram.html
# - https://numpy.org/doc/stable/reference/generated/numpy.histogram_bin_edges.html#numpy.histogram_bin_edges

# %%
dados = np.array([160, 165, 167, 164, 160, 166, 160, 161, 150, 152, 173, 160, 155,
                  164, 168, 162, 161, 168, 163, 156, 155, 169, 151, 170, 164,
                  155, 152, 163, 160, 155, 157, 156, 158, 158, 161, 154, 161, 156, 172, 153])

# %%
frequencia, classes = np.histogram(dados)

# %%
frequencia
# Out:
# array([ 5,  8,  3, 12,  5,  4,  3])

# %%
classes
# Out:
# array([150.        , 153.28571429, 156.57142857, 159.85714286,
#        163.14285714, 166.42857143, 169.71428571, 173.        ])

# %%
frequencia, classes, len(classes)
# Out:
# (array([4, 2, 7, 3, 9, 3, 5, 3, 2, 2]),
#  array([150. , 152.3, 154.6, 156.9, 159.2, 161.5, 163.8, 166.1, 168.4,
#         170.7, 173. ]),
#  11)

# %%
plt.hist(dados);

# %%
plt.hist(dados, bins = classes);

# %%
frequencia, classes = np.histogram(dados, bins=5)
frequencia, classes
# Out:
# (array([ 6, 10, 12,  8,  4]),
#  array([150. , 154.6, 159.2, 163.8, 168.4, 173. ]))

# %%
plt.hist(dados, classes);

# %%
frequencia, classes = np.histogram(dados, bins = 'sturges')
frequencia, classes
# Out:
# (array([ 5,  8,  3, 12,  5,  4,  3]),
#  array([150.        , 153.28571429, 156.57142857, 159.85714286,
#         163.14285714, 166.42857143, 169.71428571, 173.        ]))

# %%
plt.hist(dados, classes);

# %% [markdown]
# ## Distribuição de frequência e histograma com pandas e seaborn

# %%
type(dados)
# Out:
# numpy.ndarray

# %%
dataset = pd.DataFrame({'dados': dados})

# %%
dataset.head()
# Out:
#    dados
# 0    160
# 1    165
# 2    167
# 3    164
# 4    160

# %%
dataset.plot.hist();

# %%
sns.distplot(dados, hist = True, kde = True);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Exercício - idade census.csv

# %%
import pandas as pd
dataset = pd.read_csv('census.csv')

# %%
dataset.head()
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country  income
# 0   39          State-gov         77516  ...            40   United-States   <=50K
# 1   50   Self-emp-not-inc         83311  ...            13   United-States   <=50K
# 2   38            Private        215646  ...            40   United-States   <=50K
# 3   53            Private        234721  ...            40   United-States   <=50K
# 4   28            Private        338409  ...            40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
dataset['age'].max(), dataset['age'].min()
# Out:
# (90, 17)

# %%
dataset['age'].plot.hist();

# %%
dataset['age'] = pd.cut(dataset['age'], bins=[0, 17, 25, 40, 60, 90], 
                        labels=['Faixa1', "Faixa2", "Faixa3", "Faixa4", "Faixa5"])

# %%
dataset.head()
# Out:
#       age          workclass  ...  native-country  income
# 0  Faixa3          State-gov  ...   United-States   <=50K
# 1  Faixa4   Self-emp-not-inc  ...   United-States   <=50K
# 2  Faixa3            Private  ...   United-States   <=50K
# 3  Faixa4            Private  ...   United-States   <=50K
# 4  Faixa3            Private  ...            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
dataset['age'].unique()
# Out:
# ['Faixa3', 'Faixa4', 'Faixa2', 'Faixa5', 'Faixa1']
# Categories (5, object): ['Faixa1' < 'Faixa2' < 'Faixa3' < 'Faixa4' < 'Faixa5']

# %% [markdown]
# ## Regras de associação

# %%
dataset.head()
# Out:
#       age          workclass  ...  native-country  income
# 0  Faixa3          State-gov  ...   United-States   <=50K
# 1  Faixa4   Self-emp-not-inc  ...   United-States   <=50K
# 2  Faixa3            Private  ...   United-States   <=50K
# 3  Faixa4            Private  ...   United-States   <=50K
# 4  Faixa3            Private  ...            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
dataset_apriori = dataset[['age', 'workclass', 'education', 'marital-status', 'relationship', 'occupation',
                            'sex', 'native-country', 'income']]

# %%
dataset_apriori.head()
# Out:
#       age          workclass   education  ...      sex  native-country  income
# 0  Faixa3          State-gov   Bachelors  ...     Male   United-States   <=50K
# 1  Faixa4   Self-emp-not-inc   Bachelors  ...     Male   United-States   <=50K
# 2  Faixa3            Private     HS-grad  ...     Male   United-States   <=50K
# 3  Faixa4            Private        11th  ...     Male   United-States   <=50K
# 4  Faixa3            Private   Bachelors  ...   Female            Cuba   <=50K
#
# [5 rows x 9 columns]

# %%
dataset.shape
# Out:
# (8530, 15)

# %%
dataset_apriori = dataset_apriori.sample(n = 1000)
dataset_apriori.shape
# Out:
# (1000, 9)

# %%
transacoes = []
for i in range(dataset_apriori.shape[0]):
  transacoes.append([str(dataset_apriori.values[i, j]) for j in range(dataset_apriori.shape[1])])

# %%
len(transacoes)
# Out:
# 1000

# %%
transacoes[:2]
# Out:
# [['Faixa4',
#   ' Private',
#   ' Doctorate',
#   ' Married-civ-spouse',
#   ' Husband',
#   ' Prof-specialty',
#   ' Male',
#   ' United-States',
#   ' >50K'],
#  ['Faixa4',
#   ' Private',
#   ' HS-grad',
#   ' Married-civ-spouse',
#   ' Husband',
#   ' Craft-repair',
#   ' Male',
#   ' United-States',
#   ' >50K']]

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=76de1ce33cc02b577babe2c00c8d5a8df9fc239cbeafdd5756dd9dc6322a9c3e
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
from apyori import apriori

# %%
regras = apriori(transacoes, min_support = 0.3, min_confidence = 0.2)
resultados = list(regras)

# %%
len(resultados)
# Out:
# 38

# %%
resultados
# Out:
# [RelationRecord(items=frozenset({' <=50K'}), support=0.758, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' <=50K'}), confidence=0.758, lift=1.0)]),
#  RelationRecord(items=frozenset({' Female'}), support=0.325, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Female'}), confidence=0.325, lift=1.0)]),
#  RelationRecord(items=frozenset({' HS-grad'}), support=0.346, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' HS-grad'}), confidence=0.346, lift=1.0)]),
#  RelationRecord(items=frozenset({' Husband'}), support=0.405, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Husband'}), confidence=0.405, lift=1.0)]),
#  RelationRecord(items=frozenset({' Male'}), support=0.675, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Male'}), confidence=0.675, lift=1.0)]),
#  RelationRecord(items=frozenset({' Married-civ-spouse'}), support=0.464, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Married-civ-spouse'}), confidence=0.464, lift=1.0)]),
#  RelationRecord(items=frozenset({' Never-married'}), support=0.329, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Never-married'}), confidence=0.329, lift=1.0)]),
#  RelationRecord(items=frozenset({' Private'}), support=0.7, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Private'}), confidence=0.7, lift=1.0)]),
#  RelationRecord(items=frozenset({' United-States'}), support=0.894, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' United-States'}), confidence=0.894, lift=1.0)]),
#  RelationRecord(items=frozenset({'Faixa3'}), support=0.411, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Faixa3'}), confidence=0.411, lift=1.0)]),
#  RelationRecord(items=frozenset({'Faixa4'}), support=0.346, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Faixa4'}), confidence=0.346, lift=1.0)]),
#  RelationRecord(items=frozenset({' Male', ' <=50K'}), support=0.47, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Male', ' <=50K'}), confidence=0.47, lift=1.0), OrderedStatistic(items_base=frozenset({' <=50K'}), items_add=frozenset({' Male'}), confidence=0.6200527704485488, lift=0.9185966969608129), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' <=50K'}), confidence=0.6962962962962962, lift=0.9185966969608129)]),
#  RelationRecord(items=frozenset({' Never-married', ' <=50K'}), support=0.312, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Never-married', ' <=50K'}), confidence=0.312, lift=1.0), OrderedStatistic(items_base=frozenset({' <=50K'}), items_add=frozenset({' Never-married'}), confidence=0.41160949868073876, lift=1.2510927011572606), OrderedStatistic(items_base=frozenset({' Never-married'}), items_add=frozenset({' <=50K'}), confidence=0.9483282674772036, lift=1.2510927011572606)]),
#  RelationRecord(items=frozenset({' Private', ' <=50K'}), support=0.538, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Private', ' <=50K'}), confidence=0.538, lift=1.0), OrderedStatistic(items_base=frozenset({' <=50K'}), items_add=frozenset({' Private'}), confidence=0.7097625329815304, lift=1.0139464756879006), OrderedStatistic(items_base=frozenset({' Private'}), items_add=frozenset({' <=50K'}), confidence=0.7685714285714287, lift=1.0139464756879006)]),
#  RelationRecord(items=frozenset({' United-States', ' <=50K'}), support=0.67, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' <=50K', ' United-States'}), confidence=0.67, lift=1.0), OrderedStatistic(items_base=frozenset({' <=50K'}), items_add=frozenset({' United-States'}), confidence=0.8839050131926122, lift=0.988708068448112), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' <=50K'}), confidence=0.7494407158836689, lift=0.988708068448112)]),
#  RelationRecord(items=frozenset({'Faixa3', ' <=50K'}), support=0.318, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Faixa3', ' <=50K'}), confidence=0.318, lift=1.0), OrderedStatistic(items_base=frozenset({' <=50K'}), items_add=frozenset({'Faixa3'}), confidence=0.41952506596306066, lift=1.0207422529514858), OrderedStatistic(items_base=frozenset({'Faixa3'}), items_add=frozenset({' <=50K'}), confidence=0.7737226277372263, lift=1.020742252951486)]),
#  RelationRecord(items=frozenset({' HS-grad', ' United-States'}), support=0.323, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' HS-grad', ' United-States'}), confidence=0.323, lift=1.0), OrderedStatistic(items_base=frozenset({' HS-grad'}), items_add=frozenset({' United-States'}), confidence=0.9335260115606937, lift=1.0442125408956304), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' HS-grad'}), confidence=0.36129753914988816, lift=1.0442125408956306)]),
#  RelationRecord(items=frozenset({' Husband', ' Male'}), support=0.405, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Husband', ' Male'}), confidence=0.405, lift=1.0), OrderedStatistic(items_base=frozenset({' Husband'}), items_add=frozenset({' Male'}), confidence=1.0, lift=1.4814814814814814), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' Husband'}), confidence=0.6, lift=1.4814814814814814)]),
#  RelationRecord(items=frozenset({' Husband', ' Married-civ-spouse'}), support=0.405, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Husband', ' Married-civ-spouse'}), confidence=0.405, lift=1.0), OrderedStatistic(items_base=frozenset({' Husband'}), items_add=frozenset({' Married-civ-spouse'}), confidence=1.0, lift=2.155172413793103), OrderedStatistic(items_base=frozenset({' Married-civ-spouse'}), items_add=frozenset({' Husband'}), confidence=0.872844827586207, lift=2.1551724137931036)]),
#  RelationRecord(items=frozenset({' Husband', ' United-States'}), support=0.363, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Husband', ' United-States'}), confidence=0.363, lift=1.0), OrderedStatistic(items_base=frozenset({' Husband'}), items_add=frozenset({' United-States'}), confidence=0.8962962962962963, lift=1.0025685640898168), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' Husband'}), confidence=0.4060402684563758, lift=1.0025685640898168)]),
#  RelationRecord(items=frozenset({' Male', ' Married-civ-spouse'}), support=0.409, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Male', ' Married-civ-spouse'}), confidence=0.409, lift=1.0), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' Married-civ-spouse'}), confidence=0.6059259259259259, lift=1.3058748403575988), OrderedStatistic(items_base=frozenset({' Married-civ-spouse'}), items_add=frozenset({' Male'}), confidence=0.8814655172413792, lift=1.3058748403575988)]),
#  RelationRecord(items=frozenset({' Male', ' Private'}), support=0.468, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Male', ' Private'}), confidence=0.468, lift=1.0), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' Private'}), confidence=0.6933333333333334, lift=0.9904761904761906), OrderedStatistic(items_base=frozenset({' Private'}), items_add=frozenset({' Male'}), confidence=0.6685714285714287, lift=0.9904761904761906)]),
#  RelationRecord(items=frozenset({' Male', ' United-States'}), support=0.599, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Male', ' United-States'}), confidence=0.599, lift=1.0), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' United-States'}), confidence=0.8874074074074073, lift=0.9926257353550417), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' Male'}), confidence=0.6700223713646533, lift=0.9926257353550418)]),
#  RelationRecord(items=frozenset({' Private', ' Married-civ-spouse'}), support=0.309, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Private', ' Married-civ-spouse'}), confidence=0.309, lift=1.0), OrderedStatistic(items_base=frozenset({' Married-civ-spouse'}), items_add=frozenset({' Private'}), confidence=0.665948275862069, lift=0.9513546798029557), OrderedStatistic(items_base=frozenset({' Private'}), items_add=frozenset({' Married-civ-spouse'}), confidence=0.44142857142857145, lift=0.9513546798029556)]),
#  RelationRecord(items=frozenset({' Married-civ-spouse', ' United-States'}), support=0.415, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Married-civ-spouse', ' United-States'}), confidence=0.415, lift=1.0), OrderedStatistic(items_base=frozenset({' Married-civ-spouse'}), items_add=frozenset({' United-States'}), confidence=0.8943965517241378, lift=1.000443570161228), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' Married-civ-spouse'}), confidence=0.4642058165548098, lift=1.000443570161228)]),
#  RelationRecord(items=frozenset({' Private', ' United-States'}), support=0.611, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Private', ' United-States'}), confidence=0.611, lift=1.0), OrderedStatistic(items_base=frozenset({' Private'}), items_add=frozenset({' United-States'}), confidence=0.8728571428571429, lift=0.976350271652285), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' Private'}), confidence=0.6834451901565995, lift=0.9763502716522852)]),
#  RelationRecord(items=frozenset({'Faixa3', ' Private'}), support=0.304, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Faixa3', ' Private'}), confidence=0.304, lift=1.0), OrderedStatistic(items_base=frozenset({' Private'}), items_add=frozenset({'Faixa3'}), confidence=0.4342857142857143, lift=1.056656239137991), OrderedStatistic(items_base=frozenset({'Faixa3'}), items_add=frozenset({' Private'}), confidence=0.7396593673965937, lift=1.056656239137991)]),
#  RelationRecord(items=frozenset({'Faixa3', ' United-States'}), support=0.363, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Faixa3', ' United-States'}), confidence=0.363, lift=1.0), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({'Faixa3'}), confidence=0.4060402684563758, lift=0.9879325266578487), OrderedStatistic(items_base=frozenset({'Faixa3'}), items_add=frozenset({' United-States'}), confidence=0.8832116788321168, lift=0.9879325266578488)]),
#  RelationRecord(items=frozenset({'Faixa4', ' United-States'}), support=0.314, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Faixa4', ' United-States'}), confidence=0.314, lift=1.0), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({'Faixa4'}), confidence=0.3512304250559284, lift=1.0151168354217583), OrderedStatistic(items_base=frozenset({'Faixa4'}), items_add=frozenset({' United-States'}), confidence=0.9075144508670521, lift=1.0151168354217583)]),
#  RelationRecord(items=frozenset({' Male', ' Private', ' <=50K'}), support=0.328, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Male', ' Private', ' <=50K'}), confidence=0.328, lift=1.0), OrderedStatistic(items_base=frozenset({' <=50K'}), items_add=frozenset({' Male', ' Private'}), confidence=0.43271767810026385, lift=0.924610423291162), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' Private', ' <=50K'}), confidence=0.48592592592592593, lift=0.9032080407545091), OrderedStatistic(items_base=frozenset({' Private'}), items_add=frozenset({' Male', ' <=50K'}), confidence=0.46857142857142864, lift=0.9969604863221887), OrderedStatistic(items_base=frozenset({' Male', ' <=50K'}), items_add=frozenset({' Private'}), confidence=0.697872340425532, lift=0.9969604863221887), OrderedStatistic(items_base=frozenset({' Private', ' <=50K'}), items_add=frozenset({' Male'}), confidence=0.6096654275092936, lift=0.903208040754509), OrderedStatistic(items_base=frozenset({' Male', ' Private'}), items_add=frozenset({' <=50K'}), confidence=0.7008547008547008, lift=0.924610423291162)]),
#  RelationRecord(items=frozenset({' Male', ' United-States', ' <=50K'}), support=0.409, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' <=50K', ' Male', ' United-States'}), confidence=0.409, lift=1.0), OrderedStatistic(items_base=frozenset({' <=50K'}), items_add=frozenset({' Male', ' United-States'}), confidence=0.5395778364116095, lift=0.9007977235586135), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' <=50K', ' United-States'}), confidence=0.6059259259259259, lift=0.9043670536207848), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' Male', ' <=50K'}), confidence=0.45749440715883666, lift=0.9733923556570994), OrderedStatistic(items_base=frozenset({' Male', ' <=50K'}), items_add=frozenset({' United-States'}), confidence=0.8702127659574468, lift=0.9733923556570993), OrderedStatistic(items_base=frozenset({' United-States', ' <=50K'}), items_add=frozenset({' Male'}), confidence=0.6104477611940298, lift=0.9043670536207847), OrderedStatistic(items_base=frozenset({' Male', ' United-States'}), items_add=frozenset({' <=50K'}), confidence=0.682804674457429, lift=0.9007977235586134)]),
#  RelationRecord(items=frozenset({' United-States', ' Private', ' <=50K'}), support=0.462, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' <=50K', ' Private', ' United-States'}), confidence=0.462, lift=1.0), OrderedStatistic(items_base=frozenset({' <=50K'}), items_add=frozenset({' Private', ' United-States'}), confidence=0.6094986807387863, lift=0.9975428489996503), OrderedStatistic(items_base=frozenset({' Private'}), items_add=frozenset({' <=50K', ' United-States'}), confidence=0.66, lift=0.9850746268656716), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' Private', ' <=50K'}), confidence=0.5167785234899329, lift=0.96055487637534), OrderedStatistic(items_base=frozenset({' Private', ' <=50K'}), items_add=frozenset({' United-States'}), confidence=0.8587360594795539, lift=0.9605548763753399), OrderedStatistic(items_base=frozenset({' United-States', ' <=50K'}), items_add=frozenset({' Private'}), confidence=0.6895522388059702, lift=0.9850746268656717), OrderedStatistic(items_base=frozenset({' Private', ' United-States'}), items_add=frozenset({' <=50K'}), confidence=0.7561374795417349, lift=0.9975428489996503)]),
#  RelationRecord(items=frozenset({' Husband', ' Male', ' Married-civ-spouse'}), support=0.405, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Husband', ' Male', ' Married-civ-spouse'}), confidence=0.405, lift=1.0), OrderedStatistic(items_base=frozenset({' Husband'}), items_add=frozenset({' Male', ' Married-civ-spouse'}), confidence=1.0, lift=2.444987775061125), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' Husband', ' Married-civ-spouse'}), confidence=0.6, lift=1.4814814814814814), OrderedStatistic(items_base=frozenset({' Married-civ-spouse'}), items_add=frozenset({' Husband', ' Male'}), confidence=0.872844827586207, lift=2.1551724137931036), OrderedStatistic(items_base=frozenset({' Husband', ' Male'}), items_add=frozenset({' Married-civ-spouse'}), confidence=1.0, lift=2.155172413793103), OrderedStatistic(items_base=frozenset({' Husband', ' Married-civ-spouse'}), items_add=frozenset({' Male'}), confidence=1.0, lift=1.4814814814814814), OrderedStatistic(items_base=frozenset({' Male', ' Married-civ-spouse'}), items_add=frozenset({' Husband'}), confidence=0.9902200488997557, lift=2.444987775061125)]),
#  RelationRecord(items=frozenset({' Husband', ' Male', ' United-States'}), support=0.363, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Husband', ' Male', ' United-States'}), confidence=0.363, lift=1.0), OrderedStatistic(items_base=frozenset({' Husband'}), items_add=frozenset({' Male', ' United-States'}), confidence=0.8962962962962963, lift=1.496321028875286), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' Husband', ' United-States'}), confidence=0.5377777777777777, lift=1.4814814814814812), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' Husband', ' Male'}), confidence=0.4060402684563758, lift=1.0025685640898168), OrderedStatistic(items_base=frozenset({' Husband', ' Male'}), items_add=frozenset({' United-States'}), confidence=0.8962962962962963, lift=1.0025685640898168), OrderedStatistic(items_base=frozenset({' Husband', ' United-States'}), items_add=frozenset({' Male'}), confidence=1.0, lift=1.4814814814814814), OrderedStatistic(items_base=frozenset({' Male', ' United-States'}), items_add=frozenset({' Husband'}), confidence=0.6060100166944908, lift=1.496321028875286)]),
#  RelationRecord(items=frozenset({' Husband', ' Married-civ-spouse', ' United-States'}), support=0.363, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Husband', ' Married-civ-spouse', ' United-States'}), confidence=0.363, lift=1.0), OrderedStatistic(items_base=frozenset({' Husband'}), items_add=frozenset({' Married-civ-spouse', ' United-States'}), confidence=0.8962962962962963, lift=2.1597501115573405), OrderedStatistic(items_base=frozenset({' Married-civ-spouse'}), items_add=frozenset({' Husband', ' United-States'}), confidence=0.7823275862068965, lift=2.155172413793103), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' Husband', ' Married-civ-spouse'}), confidence=0.4060402684563758, lift=1.0025685640898168), OrderedStatistic(items_base=frozenset({' Husband', ' Married-civ-spouse'}), items_add=frozenset({' United-States'}), confidence=0.8962962962962963, lift=1.0025685640898168), OrderedStatistic(items_base=frozenset({' Husband', ' United-States'}), items_add=frozenset({' Married-civ-spouse'}), confidence=1.0, lift=2.155172413793103), OrderedStatistic(items_base=frozenset({' Married-civ-spouse', ' United-States'}), items_add=frozenset({' Husband'}), confidence=0.8746987951807229, lift=2.1597501115573405)]),
#  RelationRecord(items=frozenset({' Male', ' Married-civ-spouse', ' United-States'}), support=0.367, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Male', ' Married-civ-spouse', ' United-States'}), confidence=0.367, lift=1.0), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' Married-civ-spouse', ' United-States'}), confidence=0.5437037037037037, lift=1.3101294065149487), OrderedStatistic(items_base=frozenset({' Married-civ-spouse'}), items_add=frozenset({' Male', ' United-States'}), confidence=0.790948275862069, lift=1.320447872891601), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' Male', ' Married-civ-spouse'}), confidence=0.4105145413870246, lift=1.0037030351760994), OrderedStatistic(items_base=frozenset({' Male', ' Married-civ-spouse'}), items_add=frozenset({' United-States'}), confidence=0.8973105134474328, lift=1.0037030351760994), OrderedStatistic(items_base=frozenset({' Male', ' United-States'}), items_add=frozenset({' Married-civ-spouse'}), confidence=0.6126878130217028, lift=1.320447872891601), OrderedStatistic(items_base=frozenset({' Married-civ-spouse', ' United-States'}), items_add=frozenset({' Male'}), confidence=0.8843373493975903, lift=1.3101294065149485)]),
#  RelationRecord(items=frozenset({' Male', ' Private', ' United-States'}), support=0.401, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Male', ' Private', ' United-States'}), confidence=0.401, lift=1.0), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' Private', ' United-States'}), confidence=0.5940740740740741, lift=0.9722979935745893), OrderedStatistic(items_base=frozenset({' Private'}), items_add=frozenset({' Male', ' United-States'}), confidence=0.572857142857143, lift=0.9563558311471502), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' Male', ' Private'}), confidence=0.44854586129753915, lift=0.9584313275588443), OrderedStatistic(items_base=frozenset({' Male', ' Private'}), items_add=frozenset({' United-States'}), confidence=0.8568376068376068, lift=0.9584313275588443), OrderedStatistic(items_base=frozenset({' Male', ' United-States'}), items_add=frozenset({' Private'}), confidence=0.6694490818030051, lift=0.9563558311471502), OrderedStatistic(items_base=frozenset({' Private', ' United-States'}), items_add=frozenset({' Male'}), confidence=0.6563011456628478, lift=0.9722979935745892)]),
#  RelationRecord(items=frozenset({' Husband', ' Male', ' Married-civ-spouse', ' United-States'}), support=0.363, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Husband', ' Male', ' Married-civ-spouse', ' United-States'}), confidence=0.363, lift=1.0), OrderedStatistic(items_base=frozenset({' Husband'}), items_add=frozenset({' Male', ' Married-civ-spouse', ' United-States'}), confidence=0.8962962962962963, lift=2.442224240589363), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' Husband', ' Married-civ-spouse', ' United-States'}), confidence=0.5377777777777777, lift=1.4814814814814812), OrderedStatistic(items_base=frozenset({' Married-civ-spouse'}), items_add=frozenset({' Husband', ' Male', ' United-States'}), confidence=0.7823275862068965, lift=2.155172413793103), OrderedStatistic(items_base=frozenset({' United-States'}), items_add=frozenset({' Husband', ' Male', ' Married-civ-spouse'}), confidence=0.4060402684563758, lift=1.0025685640898168), OrderedStatistic(items_base=frozenset({' Husband', ' Male'}), items_add=frozenset({' Married-civ-spouse', ' United-States'}), confidence=0.8962962962962963, lift=2.1597501115573405), OrderedStatistic(items_base=frozenset({' Husband', ' Married-civ-spouse'}), items_add=frozenset({' Male', ' United-States'}), confidence=0.8962962962962963, lift=1.496321028875286), OrderedStatistic(items_base=frozenset({' Husband', ' United-States'}), items_add=frozenset({' Male', ' Married-civ-spouse'}), confidence=1.0, lift=2.444987775061125), OrderedStatistic(items_base=frozenset({' Male', ' Married-civ-spouse'}), items_add=frozenset({' Husband', ' United-States'}), confidence=0.8875305623471883, lift=2.444987775061125), OrderedStatistic(items_base=frozenset({' Male', ' United-States'}), items_add=frozenset({' Husband', ' Married-civ-spouse'}), confidence=0.6060100166944908, lift=1.496321028875286), OrderedStatistic(items_base=frozenset({' Married-civ-spouse', ' United-States'}), items_add=frozenset({' Husband', ' Male'}), confidence=0.8746987951807229, lift=2.1597501115573405), OrderedStatistic(items_base=frozenset({' Husband', ' Male', ' Married-civ-spouse'}), items_add=frozenset({' United-States'}), confidence=0.8962962962962963, lift=1.0025685640898168), OrderedStatistic(items_base=frozenset({' Husband', ' Male', ' United-States'}), items_add=frozenset({' Married-civ-spouse'}), confidence=1.0, lift=2.155172413793103), OrderedStatistic(items_base=frozenset({' Husband', ' Married-civ-spouse', ' United-States'}), items_add=frozenset({' Male'}), confidence=1.0, lift=1.4814814814814814), OrderedStatistic(items_base=frozenset({' Male', ' Married-civ-spouse', ' United-States'}), items_add=frozenset({' Husband'}), confidence=0.989100817438692, lift=2.442224240589363)])]

# %%
resultados[12]
# Out:
# RelationRecord(items=frozenset({' Never-married', ' <=50K'}), support=0.312, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Never-married', ' <=50K'}), confidence=0.312, lift=1.0), OrderedStatistic(items_base=frozenset({' <=50K'}), items_add=frozenset({' Never-married'}), confidence=0.41160949868073876, lift=1.2510927011572606), OrderedStatistic(items_base=frozenset({' Never-married'}), items_add=frozenset({' <=50K'}), confidence=0.9483282674772036, lift=1.2510927011572606)])
