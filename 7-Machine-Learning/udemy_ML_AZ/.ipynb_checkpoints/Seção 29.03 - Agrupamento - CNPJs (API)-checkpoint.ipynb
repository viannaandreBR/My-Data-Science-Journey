# %%
# Instruções basiconas de sempre.

# Lidar com dataframes.
import numpy as np
import pandas as pd

# Lidar com gráficos.
import matplotlib.pyplot as plt
import seaborn as sns
# import plotly
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from plotting import (multiple_histograms_plot,
                      bar_plot_with_categorical,
                      plot_confusion_matrix,
                      plot_confusion_matrix_2,
                      plot_roc)

# Lidar com preparação de dados.
from data_prep import data_prep as dp # Eu que fiz esse modulinho ("uuuuuuuuuma bosts!").
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (StandardScaler
                                   , MinMaxScaler)
from sklearn.model_selection import (train_test_split
                                     , cross_val_score
                                     , StratifiedKFold)

# Lidar com validação de modelos.
from sklearn.metrics import (confusion_matrix
                             , accuracy_score
                             , classification_report)

pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
#Bibliotecas necessárias para aquisitar as informações em json em requisitando uma API Rest.

import json
import requests

# %% [markdown]
# # Aquisitando os dados através de requisições a API do Brasil.IO e transformando JSON em um DataFrame
# Seguindo as instruções em uma questão do [Stackoverflow](https://stackoverflow.com/questions/21104592/json-to-pandas-dataframe), temos:

# %%
# https://brasil.io/api/dataset/documentos-brasil/documents/data

r = requests.get("https://brasil.io/api/dataset/documentos-brasil/documents/data?page="+str(numero))
if r.status_code == 200:
    json_gastos_parlamentares = json.loads(r.content)

# %%
# Requisições por número da página

df_gastos_parlamentares = pd.DataFrame(list())

for numero in range (1,11):
    r = requests.get("https://brasil.io/api/dataset/gastos-deputados/cota_parlamentar/data?page="+str(numero))
    if r.status_code == 200:
        json_gastos_parlamentares = json.loads(r.content)
        regex_equal_symbol = json_gastos_parlamentares["next"].rfind("=")
#         print(json_gastos_parlamentares["next"][regex_equal_symbol+1:])
#         print(json_gastos_parlamentares["results"][0]["numano"])
        df_gastos_parlamentares = pd.concat([df_gastos_parlamentares
                                             , pd.io.json.json_normalize(json_gastos_parlamentares["results"])]
                                            , axis=0
                                            , join="outer"
                                           )
    
print(df_gastos_parlamentares.shape)

df_gastos_parlamentares.sample(5).T
# Out:
# (10000, 29)
#                                       357             709                538  \
# codlegislatura             56              56              55
# datemissao                 None            None            None
# idecadastro                178876          160599          141500
# idedocumento               0               0               0
# indtipodocumento           0               0               0
# nucarteiraparlamentar      417             231             257
# nudeputadoid               3008            2356            1889
# nulegislatura              2019            2019            2015
# numano                     2019            2019            2018
# numespecificacaosubcota    0               0               0
# numlote                    0               0               0
# nummes                     3               10              9
# numparcela                 0               0               0
# numressarcimento           0               0               0
# numsubcota                 10              10              10
# sgpartido                  PSDB            PP              PSD
# sguf                       GO              MG              MG
# txnomeparlamentar          Célio Silveira  Dimas Fabiano   MARCOS MONTES
# txtcnpjcpf                 00000000000006  00000000000006  00000000000001
# txtdescricao               TELEFONIA       TELEFONIA       TELEFONIA
# txtdescricaoespecificacao  None            None            None
# txtfornecedor              RAMAL           RAMAL           CELULAR FUNCIONAL
# txtnumero                  6858322         6971935         6691831
# txtpassageiro              None            None            None
# txttrecho                  None            None            None
# vlrdocumento               147.39          17.00           30.90
# vlrglosa                   0.00            0.00            0.00
# vlrliquido                 147.39          17.00           30.90
# vlrrestituicao             None            None            None
#
#                                         601             434
# codlegislatura             56                55
# datemissao                 None              None
# idecadastro                133439            160582
# idedocumento               0                 0
# indtipodocumento           0                 0
# nucarteiraparlamentar      89                548
# nudeputadoid               1748              2283
# nulegislatura              2019              2015
# numano                     2019              2019
# numespecificacaosubcota    0                 0
# numlote                    0                 0
# nummes                     12                1
# numparcela                 0                 0
# numressarcimento           0                 0
# numsubcota                 10                10
# sgpartido                  PDT               PP
# sguf                       CE                MA
# txnomeparlamentar          André Figueiredo  ALBERTO FILHO
# txtcnpjcpf                 00000000000006    00000000000006
# txtdescricao               TELEFONIA         TELEFONIA
# txtdescricaoespecificacao  None              None
# txtfornecedor              RAMAL             RAMAL
# txtnumero                  6992781           6764634
# txtpassageiro              None              None
# txttrecho                  None              None
# vlrdocumento               9.92              49.21
# vlrglosa                   0.00              0.00
# vlrliquido                 9.92              49.21
# vlrrestituicao             None              None

# %%
df_gastos_parlamentares.dropna(axis=1, inplace=True)
df_gastos_parlamentares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 999
# Data columns (total 24 columns):
# codlegislatura             10000 non-null int64
# idecadastro                10000 non-null int64
# idedocumento               10000 non-null int64
# indtipodocumento           10000 non-null int64
# nucarteiraparlamentar      10000 non-null int64
# nudeputadoid               10000 non-null int64
# nulegislatura              10000 non-null int64
# numano                     10000 non-null int64
# numespecificacaosubcota    10000 non-null int64
# numlote                    10000 non-null int64
# nummes                     10000 non-null int64
# numparcela                 10000 non-null int64
# numressarcimento           10000 non-null int64
# numsubcota                 10000 non-null int64
# sgpartido                  10000 non-null object
# sguf                       10000 non-null object
# txnomeparlamentar          10000 non-null object
# txtcnpjcpf                 10000 non-null object
# txtdescricao               10000 non-null object
# txtfornecedor              10000 non-null object
# txtnumero                  10000 non-null object
# vlrdocumento               10000 non-null object
# vlrglosa                   10000 non-null object
# vlrliquido                 10000 non-null object
# dtypes: int64(14), object(10)
# memory usage: 1.5+ MB

# %%
# Removendo os atributos com cardinalidade <= 1:

lista_atributos_para_remover = list(dp.cardinalidade(df_gastos_parlamentares)[dp.cardinalidade(df_gastos_parlamentares)["Cardinalidade"] <= 1]["Atributo"].values)

df_gastos_parlamentares.drop(lista_atributos_para_remover, axis=1, inplace=True)

# %%
df_gastos_parlamentares.vlrdocumento = pd.to_numeric(df_gastos_parlamentares.vlrdocumento)
df_gastos_parlamentares.vlrliquido = pd.to_numeric(df_gastos_parlamentares.vlrliquido)

df_gastos_parlamentares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 999
# Data columns (total 22 columns):
# codlegislatura             10000 non-null int64
# idecadastro                10000 non-null int64
# idedocumento               10000 non-null int64
# indtipodocumento           10000 non-null int64
# nucarteiraparlamentar      10000 non-null int64
# nudeputadoid               10000 non-null int64
# nulegislatura              10000 non-null int64
# numano                     10000 non-null int64
# numespecificacaosubcota    10000 non-null int64
# numlote                    10000 non-null int64
# nummes                     10000 non-null int64
# numparcela                 10000 non-null int64
# numressarcimento           10000 non-null int64
# numsubcota                 10000 non-null int64
# sgpartido                  10000 non-null object
# sguf                       10000 non-null object
# txnomeparlamentar          10000 non-null object
# txtcnpjcpf                 10000 non-null object
# txtfornecedor              10000 non-null object
# txtnumero                  10000 non-null object
# vlrdocumento               10000 non-null float64
# vlrliquido                 10000 non-null float64
# dtypes: float64(2), int64(14), object(6)
# memory usage: 1.5+ MB

# %% [markdown]
# **Análise preliminar:**
#
# 1. Os atributos / fatores / variáveis independentes que possuem cardinalidade igual a um não oferecem nenhum ganho de informação. Atributos
# **Ação:** Remover esses atributos.
#
# 2. Os atributos vlrdocumento e vlrliquido estão como objects, mas são floats.
# **Ação:** Converter esses atributos para float.

# %%
dp.cardinalidade(df_gastos_parlamentares)
# Out:
#             Atributo  Cardinalidade  \
# 3  txtcnpjcpf         2
# 4  txtfornecedor      2
# 1  sguf               27
# 5  txtnumero          27
# 0  sgpartido          30
# 2  txnomeparlamentar  819
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Valores
# 3  [00000000000006, 00000000000001]
# 4  [RAMAL, CELULAR FUNCIONAL]
# 1  [ES, SP, PI, SE, BA, PE, PR, RS, MG, SC, RJ, AC, PB, PA, AM, MA, CE, GO, MS, RO, RN, TO, MT, RR, AL, DF, AP]
# 5  [7009787, 6992781, 6984585, 6971935, 6971636, 6911066, 6900895, 6867342, 6860309, 6860198, 6858322, 6836040, 6764634, 6736164, 6727723, 6691809, 6700820, 6679940, 6679981, 6691831, 6679924, 6671376, 6679326, 6679406, 6679910, 6670073, 6679324]
# 0  [DEM, PP, PDT, PODE, PSB, PT, REPUBLICANOS, CIDADANIA, PSOL, MDB, PCdoB, PSD, PL, PROS, PSDB, PSC, PTB, PSL, SOLIDARIEDADE, NOVO, AVANTE, PATRIOTA, PV, REDE, PRB, PPS, PR, PATRI, PHS, PPL]
# 2  [Norma Ayub, Fausto Pinato, Iracema Portella, Fábio Henrique, Bacelar, Felipe Carreras, Arlindo Chinaglia, Celso Russomanno, Gustavo Fruet, Rubens Bueno, Henrique Fontana, Pompeo de Mattos, Ivan Valente, Júlio Delgado, Rui Falcão, Angela Amin, Benedita da Silva, Leonardo Monteiro, Hermes Parcianello, Ricardo Barros, Renildo Calheiros, Sérgio Brito, Darcísio Perondi, Perpétua Almeida, Wellington Roberto, Bosco Costa, Alice Portugal, Daniel Almeida, Elcione Barbalho, José Priante, Átila Lins, Mário Heringer, Odair Cunha, Patrus Ananias, Reginaldo Lopes, Gastão Vieira, Carlos Sampaio, Gilberto Nascimento, Vicentinho, Leônidas Cristino, Roberto Pessoa, Júlio Cesar, Paes Landim, Nilson Pinto, Silas Câmara, João Campos, Rubens Otoni, Gonzaga Patriota, Vander Loubet, Giacobo, Maria do Rosário, Paulo Pimenta, Wolney Queiroz, Átila Lira, Damião Feliciano, André de Paula, Luciano Bivar, Claudio Cajado, José Rocha, Paulo Magalhães, Lincoln Portela, Aécio Neves, Eduardo Barbosa, Rodrigo Maia, Mauro Lopes, Luiza Erundina, Jandira Feghali, Maurício Dziedricki, Marcelo Freixo, Márcio Jerry, Chico D'Angelo, Dra. Soraya Manato, Pedro Augusto Bezerra, Santini, Leur Lomanto Júnior, Eduardo Bolsonaro, Fernando Monteiro, Stefano Aguiar, Hugo Leal, Cacá Leão, Lafayette de Andrada, Gleisi Hoffmann, Jaqueline Cassol, Benes Leocádio, Vinicius Carvalho, João Marcelo Souza, Gelson Azevedo, Darci de Matos, Adriano do Baldy, Pedro Paulo, Ronaldo Martins, Pedro Lucas Fernandes, Enio Verri, Lídice da Mata, André Figueiredo, Marcelo Moraes, Paulo Ramos, Edmilson Rodrigues, Cristiano Vale, Afonso Hamm, ...]

# %%
df_gastos_parlamentares.groupby(["sguf", "sgpartido"], axis=0)["vlrliquido"].mean().sort_values(ascending=False)
# Out:
# sguf  sgpartido
# GO    PTB              308.737143
#       MDB              294.604286
# SP    PTB              291.690000
# PA    PPS              282.832857
# SP    PPS              280.679231
# CE    DEM              280.619048
# GO    DEM              280.395000
# TO    PR               251.617143
# GO    PODE             251.564167
# SC    DEM              247.613333
# GO    PDT              234.104211
# PB    MDB              233.428571
# RO    PRB              226.663125
# MT    PRB              205.145000
# GO    PRB              199.844286
# MG    SOLIDARIEDADE    199.121053
# DF    PP               186.266111
#       PT               177.924211
# MA    PRB              175.482857
# AL    MDB              171.860000
# ES    PDT              170.300556
# SC    PR               169.662857
# CE    PSDB             165.662692
# PA    PODE             160.248333
# MG    PSDB             158.732212
# TO    PSD              157.999091
# PB    PR               156.774286
# SE    PR               154.805000
# PR    PROS             146.218000
# MG    MDB              145.467531
# BA    PR               143.030417
# PA    SOLIDARIEDADE    142.784286
# GO    PSC              142.540000
# MS    PT               140.617200
# SP    CIDADANIA        137.364167
# CE    PR               137.033182
# AL    PDT              136.880000
# GO    PSD              130.035789
# MG    DEM              129.982821
# GO    PT               129.351579
# MT    PTB              126.816667
# PE    AVANTE           125.702963
# ES    PP               124.909200
# PA    PSC              122.728571
# MA    PROS             120.934545
# CE    PTB              119.960000
# RS    PSD              119.700526
# SP    SOLIDARIEDADE    119.324211
# RJ    PP               115.835526
# AM    PRB              115.820000
# RS    PODE             115.043333
# AM    PP               114.765263
# DF    PSDB             112.014286
# PI    PSB              109.570769
# GO    REPUBLICANOS     109.473333
# DF    PR               106.021429
# PI    PP               105.132340
# TO    PL               105.093333
# SE    PDT              104.640000
# MG    PODE             104.364583
# RJ    SOLIDARIEDADE    103.804815
# SC    PPS              103.608333
# CE    MDB              103.398000
# MT    PODE             102.520000
# SC    CIDADANIA        101.501667
# MA    PV               101.363333
# GO    PP               100.933019
# ES    DEM              100.368947
# PI    PTB              99.612308
# PR    PP               99.194545
# BA    AVANTE           97.625833
# MA    MDB              96.190612
# PB    PDT              95.323684
# CE    PSB              95.316111
# RS    PR               94.830000
# MS    MDB              94.110000
# RN    PHS              93.000833
# SC    PSDB             91.464800
# PE    SOLIDARIEDADE    90.537083
# PB    PL               90.393333
# RN    PL               90.140000
# PE    PSB              89.854286
# MA    PCdoB            89.064211
# MT    PSDB             88.561667
# MA    REPUBLICANOS     87.619231
# RO    MDB              87.076000
# CE    AVANTE           86.618333
# AM    REPUBLICANOS     86.503333
# RO    PTB              86.398571
# SP    PP               85.418028
# RS    PP               85.408571
# PR    PTB              83.880455
# BA    PSB              83.841875
#       PSDB             83.525312
# RR    MDB              83.185714
# PE    PATRIOTA         82.461667
# SP    PR               81.960732
#       PT               81.957442
# BA    PCdoB            81.694474
# MS    PSB              81.626667
# MG    PROS             81.612045
# TO    PP               81.527143
# GO    PSDB             81.432333
# AL    AVANTE           80.164286
# MG    PSD              79.845316
# PR    PSD              79.695467
# GO    PPS              78.735000
# RJ    PCdoB            78.687895
# RS    PL               77.706667
# PR    PT               77.561429
# MA    PATRI            76.830000
# PR    DEM              74.810000
# SP    MDB              74.771923
# BA    PP               74.710116
# CE    PT               74.701324
# BA    PL               74.640000
# SP    PRB              74.210244
# MG    PR               73.678605
# PE    MDB              73.587895
# SP    PSDB             72.914031
# MS    DEM              72.722857
# BA    PSL              72.571667
# MT    PSL              72.244211
# RJ    PROS             72.222800
# RS    MDB              71.877778
# PI    PSD              70.161053
# SE    PSD              70.103333
# TO    DEM              69.206522
# MS    PSDB             69.146596
# PE    PROS             68.785000
# MA    PSDB             68.394444
# RR    PR               68.372632
# BA    PRB              67.979524
# PE    DEM              67.751143
#       PPS              67.508333
# MG    PP               67.462963
#       PSC              67.028750
# RR    PP               66.219444
# PR    PSC              65.899474
# SP    PSD              65.546486
# PR    PSDB             65.356154
# MG    REPUBLICANOS     65.240833
# MT    MDB              64.810256
# RR    PL               64.494167
# PE    PL               64.459167
# RN    PP               64.164000
# RS    PSL              64.121875
# PR    PR               64.078421
# PB    PSC              63.605714
# PA    DEM              63.154000
# PB    PTB              63.153889
# DF    DEM              63.112632
# AM    PHS              62.460000
# SC    MDB              62.309268
# RO    DEM              62.180000
# DF    SOLIDARIEDADE    61.955714
# MA    PATRIOTA         61.428333
# BA    MDB              61.131429
# PE    PATRI            60.753333
# MG    PL               60.746667
# SE    MDB              60.696111
# PR    REPUBLICANOS     60.658333
# PE    REPUBLICANOS     60.437500
# SP    PCdoB            59.880000
# AC    PDT              59.615000
# RJ    PT               59.504615
#       PSB              58.859474
# MG    PT               58.812216
# PI    DEM              58.617143
# ES    PCdoB            58.433333
# GO    PSL              58.185667
# BA    PSD              58.056364
# SP    PV               57.817200
# RS    PTB              57.617755
# ES    MDB              57.605714
# AC    DEM              57.510556
# CE    PSD              57.083158
# PR    MDB              56.890682
# DF    PRB              56.506667
# PA    MDB              56.492045
# MT    PT               56.286316
# RO    PODE             56.244167
# PA    PSD              56.238846
# RJ    PTB              56.197778
# RN    PSD              55.673182
# RR    DEM              55.540000
# RJ    PR               55.340000
# RR    PSDB             55.222222
# SC    PSD              55.134419
# SE    PT               55.112778
# MA    PSC              55.102917
# RS    NOVO             55.051667
# SP    PSB              54.785758
# RN    MDB              54.530000
# AC    MDB              54.090541
# BA    PATRI            54.088182
# MG    PSB              54.014651
# RS    PSDB             53.725161
# BA    PTB              53.460000
# AL    PP               52.965789
# RJ    MDB              52.370000
#       PATRI            52.335385
#       DEM              52.130093
# ES    PL               52.112500
# MG    PDT              51.578649
# RN    DEM              51.237143
# BA    PODE             51.188421
# MS    PSL              50.903333
# ES    PSB              50.439687
# RJ    PL               50.163061
# SC    REPUBLICANOS     50.065833
# MG    PSL              49.996667
# PA    PT               49.564211
# AM    DEM              49.384286
# SP    DEM              49.130957
# PR    PV               49.055000
# RS    PT               48.726694
# RJ    PSD              48.689140
# PE    PSDB             48.646923
#       PSD              48.623158
# MA    PTB              48.216842
# BA    PT               47.853893
# PB    PP               47.802963
# AL    PTB              47.756250
# AC    PSDB             47.276190
# PB    DEM              47.241053
# CE    PDT              47.123933
# RR    SOLIDARIEDADE    47.004167
# PR    PL               46.771944
# MT    SOLIDARIEDADE    46.745833
# MG    PATRIOTA         46.638750
# MA    SOLIDARIEDADE    46.600000
# MG    PCdoB            46.507000
# PA    PL               46.468333
# PE    PP               46.361333
# AL    PR               45.945000
# MA    PDT              45.464000
# PI    PR               45.106667
# SC    PT               44.900000
#       PP               44.867917
# PB    PSDB             44.811702
# GO    PATRIOTA         44.770833
# SP    PODE             44.639841
# PB    PT               44.287368
# RN    PSDB             44.238571
# SP    PL               43.961071
# AL    PT               43.952222
# PA    PTB              43.934516
# MG    PHS              43.872500
# PR    PSB              43.377143
# MT    PP               43.243889
# MA    PSD              43.075833
# PE    PR               42.918333
# ES    CIDADANIA        42.497500
# SP    PSOL             42.309200
# TO    MDB              41.987619
# DF    PV               41.905000
# RS    PDT              41.798077
# PB    PRB              41.176667
# SE    PP               40.960870
# PA    PP               40.863333
# PR    CIDADANIA        40.577500
#       PPS              40.472857
# SP    PSL              40.387603
# PB    PROS             40.307778
# DF    PSD              40.197500
# BA    DEM              39.986860
# AP    PP               39.741600
# RO    PP               39.629167
#       PSL              39.365833
# PE    PDT              39.059355
# AC    PCdoB            38.909167
# DF    PODE             38.663333
# BA    PDT              38.563000
# DF    PL               38.400833
# AM    PL               38.399167
# AL    REPUBLICANOS     38.023333
# PA    PR               37.613333
# RN    PSB              37.462778
# RJ    PSOL             37.100000
# ES    PSL              36.990000
# AP    PL               36.957273
#       PDT              36.642500
# SP    REPUBLICANOS     36.598889
# AP    MDB              36.257143
# CE    PCdoB            36.175714
# RS    REDE             36.105000
# PE    PSL              35.840000
# AM    PCdoB            35.826667
# PE    CIDADANIA        35.740833
# MT    DEM              35.120000
# PA    PDT              35.080000
# PE    PTB              35.073077
# AL    PSD              34.683889
# AM    PSL              34.353333
# MG    CIDADANIA        34.316667
# ES    REPUBLICANOS     34.168333
# RJ    PSDB             34.166667
# BA    REPUBLICANOS     34.077500
# AP    AVANTE           33.740833
# RS    PSB              33.613514
# AC    PSD              33.550000
# TO    PSC              33.347500
# RJ    REPUBLICANOS     33.095000
# AC    PT               33.002609
# MS    PRB              32.600000
# PI    PDT              32.277500
# PB    PSB              32.177778
# RO    PDT              31.819167
# AC    REPUBLICANOS     31.805000
# MA    PODE             31.750000
# TO    PT               31.463571
# MS    PDT              31.398571
# RJ    AVANTE           31.223333
# RO    PSDB             31.184444
# SE    PL               30.974167
# AM    PDT              30.933333
# RR    PRB              30.863000
# DF    PSL              30.809167
# PI    PL               30.746667
# GO    SOLIDARIEDADE    30.644444
# RJ    CIDADANIA        30.613333
# DF    REPUBLICANOS     30.603333
# RO    PR               30.565000
# PI    MDB              30.291053
# RS    PRB              30.228333
#       REPUBLICANOS     30.063333
# PI    PT               29.896000
# AP    PSB              29.883158
# RJ    NOVO             29.598333
# PB    REPUBLICANOS     29.408333
# MG    AVANTE           29.359318
# TO    PROS             29.222857
# PR    PODE             28.247222
# GO    PR               28.106667
# CE    PP               28.051667
# AM    PSD              27.704167
# TO    PRB              27.690000
#       SOLIDARIEDADE    27.641667
# SE    PSB              27.310000
# AL    PL               27.194167
# PR    PSL              26.942857
# RJ    PDT              26.588718
# RO    PSB              26.450833
# PE    PSC              26.369167
# MS    PSD              26.270500
# CE    PRB              26.162857
# MA    PL               25.643333
# PA    PSB              25.592500
# CE    SOLIDARIEDADE    25.305714
# PE    PODE             25.276818
# AP    PSD              24.885000
# AM    PSDB             24.590909
# AL    PSB              24.320556
# SC    SOLIDARIEDADE    23.900000
# AM    SOLIDARIEDADE    23.845000
# RJ    PODE             23.515000
# PE    PT               23.463750
# RJ    PSL              23.457829
# RR    PSL              23.411667
# MA    DEM              23.396667
# PA    PSDB             23.258065
# AP    PODE             22.992500
#       REPUBLICANOS     22.810000
# MA    PT               22.524444
# BA    PPL              22.315000
# MG    NOVO             22.027917
# AP    PR               22.025714
# MG    PSOL             21.739167
# SE    PSC              21.680556
# RO    PSD              21.563333
# PE    PCdoB            21.532222
# RN    REPUBLICANOS     21.260000
# SE    PRB              20.926667
# GO    PL               20.540833
# BA    PROS             20.442500
# AP    PCdoB            20.393889
# CE    PL               20.182083
#       PV               20.142500
# AL    PHS              19.840000
# RR    PSD              19.809167
# PR    PDT              19.795789
# RR    PHS              19.540000
# PB    PSL              19.501667
# MA    PSB              19.263333
# ES    PT               19.216667
# AL    PSDB             18.915000
# MA    PP               18.906957
# SP    PSC              18.026000
# ES    SOLIDARIEDADE    17.893333
# CE    PROS             17.327222
# RJ    PSC              17.244167
# SC    PSL              16.837500
# AP    PSDB             16.613333
# SP    NOVO             16.576389
# RJ    REDE             16.364286
# PA    REPUBLICANOS     15.690833
# AM    MDB              14.717500
# GO    PSB              13.570000
# SP    PDT              13.352500
# SC    NOVO             12.578333
# SE    SOLIDARIEDADE    12.395833
# CE    PSL              12.151667
# RR    REPUBLICANOS     12.025833
# MA    PPS              11.271667
# AP    PROS             11.086667
# PA    PSOL             10.688421
# SC    PSB              9.117500
# RN    PODE             9.015000
# RS    DEM              8.992500
# PI    SOLIDARIEDADE    8.726667
# BA    PSC              8.608333
# AC    SOLIDARIEDADE    8.600833
# RS    PSOL             7.850000
# AM    PR               7.593333
# RJ    PRB              6.455000
# CE    REPUBLICANOS     6.150000
# RR    REDE             5.290000
# RN    PSL              4.749167
# AM    PT               4.118333
# CE    PODE             3.826000
# RN    PT               3.353636
# AC    PSB              1.348333
# Name: vlrliquido, dtype: float64
