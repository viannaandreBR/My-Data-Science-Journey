# %%
import numpy as np
import pandas as pd

# Lidar com gráficos.
import matplotlib.pyplot as plt
import seaborn as sns
# import plotly
from bokeh.plotting import figure
from bokeh.io import show, output_notebook

# Lidar com preparação de dados.
# from data_prep import data_prep as dp # Eu que fiz esse modulinho ("uuuuuuuuuma bosts!").
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (StandardScaler
                                   , MinMaxScaler)
from sklearn.model_selection import (train_test_split
                                     , cross_val_score
                                     , StratifiedKFold)

# Lidar com validação de modelos.
from sklearn.metrics import (confusion_matrix
                             , accuracy_score
                             , classification_report)

pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
def breveDescricao(df):
    """
    Função breveDescricao

    Objetivo: Exclui atributos que estejam com colunas com todos os valores
    'NaN'. Imprime na tela a quantidade de atributos/campos e a quantidade
    de registros.

    Argumentos: um DataFrame.
    """

    df.dropna(axis=1, how="all", inplace=True)

    print("O data set possui: \n- {} atributos/campos; e \n- {} registros.\n".
      format(df.shape[1], df.shape[0]))
    df.info()



def serieNulos(df, corte = 50):
    """
     responsável: Suto
     data: 04/05/19

    objetivo: essa função retorna uma tupla com:
             (1) contendo uma pd.series com os atributos com maior
             proporção de nulos; e
             (2) uma string indicando quantos atributos estão com uma
             proporção de nulos acima do corte dado.
             argumentos: são necessários 2 argumentos:
             (1) dataframe df - base que se deseja verificar quantos nulos
             têm; e
             (2) float corte - número entre 0 e 100 para indicar o valor
             mínimo da proporção de nulos. 

    Argumentos: Um DataFrame e um corte em porcentagem (valor padrão é 50%).

    """
    serie = (df.isnull().sum().sort_values(ascending=False)/len(df))*100
    return (serie[serie > corte], ("-> {} atributos/features/campos possuem mais de {}% de valores nulos.".
            format(len(serie[serie > corte]),corte)))

def cardinalidade(df):
    """
    responsável: suto
    data: 27/10/19
    objetivo:   essa função retorna um dataframe com os atributos não
                numéricos e sua respectiva cardinalidade em ordem crescente. 
    Argumentos: somente 01 (um) argumento, o DataFrame que se deseja
                analisar.
    """
    import pandas as pd

    df_temporario = df.select_dtypes(exclude=["int64", "float64"])

    matriz_cardialidade = []

    for i, coluna in df_temporario.items():
        matriz_cardialidade.append([i, len(df_temporario[i].unique()), df_temporario[i].unique()])

    matriz_cardialidade = pd.DataFrame(matriz_cardialidade, columns=["Atributo", "Cardinalidade", "Valores"])
    matriz_cardialidade.sort_values(by="Cardinalidade", inplace=True, ascending=True)

    return matriz_cardialidade

# %%
df = pd.read_excel("../input/covid19/dataset.xlsx")
df.sample(5).T
# Out:
#                                                                   1866  \
# Patient ID                                             462dd14016e812c
# Patient age quantile                                   13
# SARS-Cov-2 exam result                                 negative
# Patient addmited to regular ward (1=yes, 0=no)         0
# Patient addmited to semi-intensive unit (1=yes, 0=no)  0
# Patient addmited to intensive care unit (1=yes, 0=no)  0
# Hematocrit                                             NaN
# Hemoglobin                                             NaN
# Platelets                                              NaN
# Mean platelet volume                                   NaN
# Red blood Cells                                        NaN
# Lymphocytes                                            NaN
# Mean corpuscular hemoglobin concentration (MCHC)       NaN
# Leukocytes                                             NaN
# Basophils                                              NaN
# Mean corpuscular hemoglobin (MCH)                      NaN
# Eosinophils                                            NaN
# Mean corpuscular volume (MCV)                          NaN
# Monocytes                                              NaN
# Red blood cell distribution width (RDW)                NaN
# Serum Glucose                                          NaN
# Respiratory Syncytial Virus                            NaN
# Influenza A                                            NaN
# Influenza B                                            NaN
# Parainfluenza 1                                        NaN
# CoronavirusNL63                                        NaN
# Rhinovirus/Enterovirus                                 NaN
# Mycoplasma pneumoniae                                  NaN
# Coronavirus HKU1                                       NaN
# Parainfluenza 3                                        NaN
# Chlamydophila pneumoniae                               NaN
# Adenovirus                                             NaN
# Parainfluenza 4                                        NaN
# Coronavirus229E                                        NaN
# CoronavirusOC43                                        NaN
# Inf A H1N1 2009                                        NaN
# Bordetella pertussis                                   NaN
# Metapneumovirus                                        NaN
# Parainfluenza 2                                        NaN
# Neutrophils                                            NaN
# Urea                                                   NaN
# Proteina C reativa mg/dL                               NaN
# Creatinine                                             NaN
# Potassium                                              NaN
# Sodium                                                 NaN
# Influenza B, rapid test                                NaN
# Influenza A, rapid test                                NaN
# Alanine transaminase                                   NaN
# Aspartate transaminase                                 NaN
# Gamma-glutamyltransferase                              NaN
# Total Bilirubin                                        NaN
# Direct Bilirubin                                       NaN
# Indirect Bilirubin                                     NaN
# Alkaline phosphatase                                   NaN
# Ionized calcium                                        NaN
# Strepto A                                              NaN
# Magnesium                                              NaN
# pCO2 (venous blood gas analysis)                       NaN
# Hb saturation (venous blood gas analysis)              NaN
# Base excess (venous blood gas analysis)                NaN
# pO2 (venous blood gas analysis)                        NaN
# Fio2 (venous blood gas analysis)                       NaN
# Total CO2 (venous blood gas analysis)                  NaN
# pH (venous blood gas analysis)                         NaN
# HCO3 (venous blood gas analysis)                       NaN
# Rods #                                                 NaN
# Segmented                                              NaN
# Promyelocytes                                          NaN
# Metamyelocytes                                         NaN
# Myelocytes                                             NaN
# Myeloblasts                                            NaN
# Urine - Esterase                                       NaN
# Urine - Aspect                                         NaN
# Urine - pH                                             NaN
# Urine - Hemoglobin                                     NaN
# Urine - Bile pigments                                  NaN
# Urine - Ketone Bodies                                  NaN
# Urine - Nitrite                                        NaN
# Urine - Density                                        NaN
# Urine - Urobilinogen                                   NaN
# Urine - Protein                                        NaN
# Urine - Sugar                                          NaN
# Urine - Leukocytes                                     NaN
# Urine - Crystals                                       NaN
# Urine - Red blood cells                                NaN
# Urine - Hyaline cylinders                              NaN
# Urine - Granular cylinders                             NaN
# Urine - Yeasts                                         NaN
# Urine - Color                                          NaN
# Partial thromboplastin time (PTT)                      NaN
# Relationship (Patient/Normal)                          NaN
# International normalized ratio (INR)                   NaN
# Lactic Dehydrogenase                                   NaN
# Prothrombin time (PT), Activity                        NaN
# Vitamin B12                                            NaN
# Creatine phosphokinase (CPK)                           NaN
# Ferritin                                               NaN
# Arterial Lactic Acid                                   NaN
# Lipase dosage                                          NaN
# D-Dimer                                                NaN
# Albumin                                                NaN
# Hb saturation (arterial blood gases)                   NaN
# pCO2 (arterial blood gas analysis)                     NaN
# Base excess (arterial blood gas analysis)              NaN
# pH (arterial blood gas analysis)                       NaN
# Total CO2 (arterial blood gas analysis)                NaN
# HCO3 (arterial blood gas analysis)                     NaN
# pO2 (arterial blood gas analysis)                      NaN
# Arteiral Fio2                                          NaN
# Phosphor                                               NaN
# ctO2 (arterial blood gas analysis)                     NaN
#
#                                                                    996  \
# Patient ID                                             c2bd5315b9372ad
# Patient age quantile                                   0
# SARS-Cov-2 exam result                                 negative
# Patient addmited to regular ward (1=yes, 0=no)         0
# Patient addmited to semi-intensive unit (1=yes, 0=no)  0
# Patient addmited to intensive care unit (1=yes, 0=no)  0
# Hematocrit                                             NaN
# Hemoglobin                                             NaN
# Platelets                                              NaN
# Mean platelet volume                                   NaN
# Red blood Cells                                        NaN
# Lymphocytes                                            NaN
# Mean corpuscular hemoglobin concentration (MCHC)       NaN
# Leukocytes                                             NaN
# Basophils                                              NaN
# Mean corpuscular hemoglobin (MCH)                      NaN
# Eosinophils                                            NaN
# Mean corpuscular volume (MCV)                          NaN
# Monocytes                                              NaN
# Red blood cell distribution width (RDW)                NaN
# Serum Glucose                                          NaN
# Respiratory Syncytial Virus                            NaN
# Influenza A                                            NaN
# Influenza B                                            NaN
# Parainfluenza 1                                        NaN
# CoronavirusNL63                                        NaN
# Rhinovirus/Enterovirus                                 NaN
# Mycoplasma pneumoniae                                  NaN
# Coronavirus HKU1                                       NaN
# Parainfluenza 3                                        NaN
# Chlamydophila pneumoniae                               NaN
# Adenovirus                                             NaN
# Parainfluenza 4                                        NaN
# Coronavirus229E                                        NaN
# CoronavirusOC43                                        NaN
# Inf A H1N1 2009                                        NaN
# Bordetella pertussis                                   NaN
# Metapneumovirus                                        NaN
# Parainfluenza 2                                        NaN
# Neutrophils                                            NaN
# Urea                                                   NaN
# Proteina C reativa mg/dL                               NaN
# Creatinine                                             NaN
# Potassium                                              NaN
# Sodium                                                 NaN
# Influenza B, rapid test                                positive
# Influenza A, rapid test                                negative
# Alanine transaminase                                   NaN
# Aspartate transaminase                                 NaN
# Gamma-glutamyltransferase                              NaN
# Total Bilirubin                                        NaN
# Direct Bilirubin                                       NaN
# Indirect Bilirubin                                     NaN
# Alkaline phosphatase                                   NaN
# Ionized calcium                                        NaN
# Strepto A                                              NaN
# Magnesium                                              NaN
# pCO2 (venous blood gas analysis)                       NaN
# Hb saturation (venous blood gas analysis)              NaN
# Base excess (venous blood gas analysis)                NaN
# pO2 (venous blood gas analysis)                        NaN
# Fio2 (venous blood gas analysis)                       NaN
# Total CO2 (venous blood gas analysis)                  NaN
# pH (venous blood gas analysis)                         NaN
# HCO3 (venous blood gas analysis)                       NaN
# Rods #                                                 NaN
# Segmented                                              NaN
# Promyelocytes                                          NaN
# Metamyelocytes                                         NaN
# Myelocytes                                             NaN
# Myeloblasts                                            NaN
# Urine - Esterase                                       NaN
# Urine - Aspect                                         NaN
# Urine - pH                                             NaN
# Urine - Hemoglobin                                     NaN
# Urine - Bile pigments                                  NaN
# Urine - Ketone Bodies                                  NaN
# Urine - Nitrite                                        NaN
# Urine - Density                                        NaN
# Urine - Urobilinogen                                   NaN
# Urine - Protein                                        NaN
# Urine - Sugar                                          NaN
# Urine - Leukocytes                                     NaN
# Urine - Crystals                                       NaN
# Urine - Red blood cells                                NaN
# Urine - Hyaline cylinders                              NaN
# Urine - Granular cylinders                             NaN
# Urine - Yeasts                                         NaN
# Urine - Color                                          NaN
# Partial thromboplastin time (PTT)                      NaN
# Relationship (Patient/Normal)                          NaN
# International normalized ratio (INR)                   NaN
# Lactic Dehydrogenase                                   NaN
# Prothrombin time (PT), Activity                        NaN
# Vitamin B12                                            NaN
# Creatine phosphokinase (CPK)                           NaN
# Ferritin                                               NaN
# Arterial Lactic Acid                                   NaN
# Lipase dosage                                          NaN
# D-Dimer                                                NaN
# Albumin                                                NaN
# Hb saturation (arterial blood gases)                   NaN
# pCO2 (arterial blood gas analysis)                     NaN
# Base excess (arterial blood gas analysis)              NaN
# pH (arterial blood gas analysis)                       NaN
# Total CO2 (arterial blood gas analysis)                NaN
# HCO3 (arterial blood gas analysis)                     NaN
# pO2 (arterial blood gas analysis)                      NaN
# Arteiral Fio2                                          NaN
# Phosphor                                               NaN
# ctO2 (arterial blood gas analysis)                     NaN
#
#                                                                   3155  \
# Patient ID                                             b55015ac4920a86
# Patient age quantile                                   3
# SARS-Cov-2 exam result                                 negative
# Patient addmited to regular ward (1=yes, 0=no)         0
# Patient addmited to semi-intensive unit (1=yes, 0=no)  0
# Patient addmited to intensive care unit (1=yes, 0=no)  0
# Hematocrit                                             NaN
# Hemoglobin                                             NaN
# Platelets                                              NaN
# Mean platelet volume                                   NaN
# Red blood Cells                                        NaN
# Lymphocytes                                            NaN
# Mean corpuscular hemoglobin concentration (MCHC)       NaN
# Leukocytes                                             NaN
# Basophils                                              NaN
# Mean corpuscular hemoglobin (MCH)                      NaN
# Eosinophils                                            NaN
# Mean corpuscular volume (MCV)                          NaN
# Monocytes                                              NaN
# Red blood cell distribution width (RDW)                NaN
# Serum Glucose                                          NaN
# Respiratory Syncytial Virus                            NaN
# Influenza A                                            NaN
# Influenza B                                            NaN
# Parainfluenza 1                                        NaN
# CoronavirusNL63                                        NaN
# Rhinovirus/Enterovirus                                 NaN
# Mycoplasma pneumoniae                                  NaN
# Coronavirus HKU1                                       NaN
# Parainfluenza 3                                        NaN
# Chlamydophila pneumoniae                               NaN
# Adenovirus                                             NaN
# Parainfluenza 4                                        NaN
# Coronavirus229E                                        NaN
# CoronavirusOC43                                        NaN
# Inf A H1N1 2009                                        NaN
# Bordetella pertussis                                   NaN
# Metapneumovirus                                        NaN
# Parainfluenza 2                                        NaN
# Neutrophils                                            NaN
# Urea                                                   NaN
# Proteina C reativa mg/dL                               NaN
# Creatinine                                             NaN
# Potassium                                              NaN
# Sodium                                                 NaN
# Influenza B, rapid test                                NaN
# Influenza A, rapid test                                NaN
# Alanine transaminase                                   NaN
# Aspartate transaminase                                 NaN
# Gamma-glutamyltransferase                              NaN
# Total Bilirubin                                        NaN
# Direct Bilirubin                                       NaN
# Indirect Bilirubin                                     NaN
# Alkaline phosphatase                                   NaN
# Ionized calcium                                        NaN
# Strepto A                                              NaN
# Magnesium                                              NaN
# pCO2 (venous blood gas analysis)                       NaN
# Hb saturation (venous blood gas analysis)              NaN
# Base excess (venous blood gas analysis)                NaN
# pO2 (venous blood gas analysis)                        NaN
# Fio2 (venous blood gas analysis)                       NaN
# Total CO2 (venous blood gas analysis)                  NaN
# pH (venous blood gas analysis)                         NaN
# HCO3 (venous blood gas analysis)                       NaN
# Rods #                                                 NaN
# Segmented                                              NaN
# Promyelocytes                                          NaN
# Metamyelocytes                                         NaN
# Myelocytes                                             NaN
# Myeloblasts                                            NaN
# Urine - Esterase                                       NaN
# Urine - Aspect                                         NaN
# Urine - pH                                             NaN
# Urine - Hemoglobin                                     NaN
# Urine - Bile pigments                                  NaN
# Urine - Ketone Bodies                                  NaN
# Urine - Nitrite                                        NaN
# Urine - Density                                        NaN
# Urine - Urobilinogen                                   NaN
# Urine - Protein                                        NaN
# Urine - Sugar                                          NaN
# Urine - Leukocytes                                     NaN
# Urine - Crystals                                       NaN
# Urine - Red blood cells                                NaN
# Urine - Hyaline cylinders                              NaN
# Urine - Granular cylinders                             NaN
# Urine - Yeasts                                         NaN
# Urine - Color                                          NaN
# Partial thromboplastin time (PTT)                      NaN
# Relationship (Patient/Normal)                          NaN
# International normalized ratio (INR)                   NaN
# Lactic Dehydrogenase                                   NaN
# Prothrombin time (PT), Activity                        NaN
# Vitamin B12                                            NaN
# Creatine phosphokinase (CPK)                           NaN
# Ferritin                                               NaN
# Arterial Lactic Acid                                   NaN
# Lipase dosage                                          NaN
# D-Dimer                                                NaN
# Albumin                                                NaN
# Hb saturation (arterial blood gases)                   NaN
# pCO2 (arterial blood gas analysis)                     NaN
# Base excess (arterial blood gas analysis)              NaN
# pH (arterial blood gas analysis)                       NaN
# Total CO2 (arterial blood gas analysis)                NaN
# HCO3 (arterial blood gas analysis)                     NaN
# pO2 (arterial blood gas analysis)                      NaN
# Arteiral Fio2                                          NaN
# Phosphor                                               NaN
# ctO2 (arterial blood gas analysis)                     NaN
#
#                                                                   3393  \
# Patient ID                                             280c15198774b3c
# Patient age quantile                                   8
# SARS-Cov-2 exam result                                 positive
# Patient addmited to regular ward (1=yes, 0=no)         0
# Patient addmited to semi-intensive unit (1=yes, 0=no)  0
# Patient addmited to intensive care unit (1=yes, 0=no)  0
# Hematocrit                                             NaN
# Hemoglobin                                             NaN
# Platelets                                              NaN
# Mean platelet volume                                   NaN
# Red blood Cells                                        NaN
# Lymphocytes                                            NaN
# Mean corpuscular hemoglobin concentration (MCHC)       NaN
# Leukocytes                                             NaN
# Basophils                                              NaN
# Mean corpuscular hemoglobin (MCH)                      NaN
# Eosinophils                                            NaN
# Mean corpuscular volume (MCV)                          NaN
# Monocytes                                              NaN
# Red blood cell distribution width (RDW)                NaN
# Serum Glucose                                          NaN
# Respiratory Syncytial Virus                            NaN
# Influenza A                                            NaN
# Influenza B                                            NaN
# Parainfluenza 1                                        NaN
# CoronavirusNL63                                        NaN
# Rhinovirus/Enterovirus                                 NaN
# Mycoplasma pneumoniae                                  NaN
# Coronavirus HKU1                                       NaN
# Parainfluenza 3                                        NaN
# Chlamydophila pneumoniae                               NaN
# Adenovirus                                             NaN
# Parainfluenza 4                                        NaN
# Coronavirus229E                                        NaN
# CoronavirusOC43                                        NaN
# Inf A H1N1 2009                                        NaN
# Bordetella pertussis                                   NaN
# Metapneumovirus                                        NaN
# Parainfluenza 2                                        NaN
# Neutrophils                                            NaN
# Urea                                                   NaN
# Proteina C reativa mg/dL                               NaN
# Creatinine                                             NaN
# Potassium                                              NaN
# Sodium                                                 NaN
# Influenza B, rapid test                                NaN
# Influenza A, rapid test                                NaN
# Alanine transaminase                                   NaN
# Aspartate transaminase                                 NaN
# Gamma-glutamyltransferase                              NaN
# Total Bilirubin                                        NaN
# Direct Bilirubin                                       NaN
# Indirect Bilirubin                                     NaN
# Alkaline phosphatase                                   NaN
# Ionized calcium                                        NaN
# Strepto A                                              NaN
# Magnesium                                              NaN
# pCO2 (venous blood gas analysis)                       NaN
# Hb saturation (venous blood gas analysis)              NaN
# Base excess (venous blood gas analysis)                NaN
# pO2 (venous blood gas analysis)                        NaN
# Fio2 (venous blood gas analysis)                       NaN
# Total CO2 (venous blood gas analysis)                  NaN
# pH (venous blood gas analysis)                         NaN
# HCO3 (venous blood gas analysis)                       NaN
# Rods #                                                 NaN
# Segmented                                              NaN
# Promyelocytes                                          NaN
# Metamyelocytes                                         NaN
# Myelocytes                                             NaN
# Myeloblasts                                            NaN
# Urine - Esterase                                       NaN
# Urine - Aspect                                         NaN
# Urine - pH                                             NaN
# Urine - Hemoglobin                                     NaN
# Urine - Bile pigments                                  NaN
# Urine - Ketone Bodies                                  NaN
# Urine - Nitrite                                        NaN
# Urine - Density                                        NaN
# Urine - Urobilinogen                                   NaN
# Urine - Protein                                        NaN
# Urine - Sugar                                          NaN
# Urine - Leukocytes                                     NaN
# Urine - Crystals                                       NaN
# Urine - Red blood cells                                NaN
# Urine - Hyaline cylinders                              NaN
# Urine - Granular cylinders                             NaN
# Urine - Yeasts                                         NaN
# Urine - Color                                          NaN
# Partial thromboplastin time (PTT)                      NaN
# Relationship (Patient/Normal)                          NaN
# International normalized ratio (INR)                   NaN
# Lactic Dehydrogenase                                   NaN
# Prothrombin time (PT), Activity                        NaN
# Vitamin B12                                            NaN
# Creatine phosphokinase (CPK)                           NaN
# Ferritin                                               NaN
# Arterial Lactic Acid                                   NaN
# Lipase dosage                                          NaN
# D-Dimer                                                NaN
# Albumin                                                NaN
# Hb saturation (arterial blood gases)                   NaN
# pCO2 (arterial blood gas analysis)                     NaN
# Base excess (arterial blood gas analysis)              NaN
# pH (arterial blood gas analysis)                       NaN
# Total CO2 (arterial blood gas analysis)                NaN
# HCO3 (arterial blood gas analysis)                     NaN
# pO2 (arterial blood gas analysis)                      NaN
# Arteiral Fio2                                          NaN
# Phosphor                                               NaN
# ctO2 (arterial blood gas analysis)                     NaN
#
#                                                                   5630
# Patient ID                                             6cd6dce7215ecb1
# Patient age quantile                                   6
# SARS-Cov-2 exam result                                 negative
# Patient addmited to regular ward (1=yes, 0=no)         0
# Patient addmited to semi-intensive unit (1=yes, 0=no)  0
# Patient addmited to intensive care unit (1=yes, 0=no)  0
# Hematocrit                                             NaN
# Hemoglobin                                             NaN
# Platelets                                              NaN
# Mean platelet volume                                   NaN
# Red blood Cells                                        NaN
# Lymphocytes                                            NaN
# Mean corpuscular hemoglobin concentration (MCHC)       NaN
# Leukocytes                                             NaN
# Basophils                                              NaN
# Mean corpuscular hemoglobin (MCH)                      NaN
# Eosinophils                                            NaN
# Mean corpuscular volume (MCV)                          NaN
# Monocytes                                              NaN
# Red blood cell distribution width (RDW)                NaN
# Serum Glucose                                          NaN
# Respiratory Syncytial Virus                            NaN
# Influenza A                                            NaN
# Influenza B                                            NaN
# Parainfluenza 1                                        NaN
# CoronavirusNL63                                        NaN
# Rhinovirus/Enterovirus                                 NaN
# Mycoplasma pneumoniae                                  NaN
# Coronavirus HKU1                                       NaN
# Parainfluenza 3                                        NaN
# Chlamydophila pneumoniae                               NaN
# Adenovirus                                             NaN
# Parainfluenza 4                                        NaN
# Coronavirus229E                                        NaN
# CoronavirusOC43                                        NaN
# Inf A H1N1 2009                                        NaN
# Bordetella pertussis                                   NaN
# Metapneumovirus                                        NaN
# Parainfluenza 2                                        NaN
# Neutrophils                                            NaN
# Urea                                                   NaN
# Proteina C reativa mg/dL                               NaN
# Creatinine                                             NaN
# Potassium                                              NaN
# Sodium                                                 NaN
# Influenza B, rapid test                                NaN
# Influenza A, rapid test                                NaN
# Alanine transaminase                                   NaN
# Aspartate transaminase                                 NaN
# Gamma-glutamyltransferase                              NaN
# Total Bilirubin                                        NaN
# Direct Bilirubin                                       NaN
# Indirect Bilirubin                                     NaN
# Alkaline phosphatase                                   NaN
# Ionized calcium                                        NaN
# Strepto A                                              NaN
# Magnesium                                              NaN
# pCO2 (venous blood gas analysis)                       NaN
# Hb saturation (venous blood gas analysis)              NaN
# Base excess (venous blood gas analysis)                NaN
# pO2 (venous blood gas analysis)                        NaN
# Fio2 (venous blood gas analysis)                       NaN
# Total CO2 (venous blood gas analysis)                  NaN
# pH (venous blood gas analysis)                         NaN
# HCO3 (venous blood gas analysis)                       NaN
# Rods #                                                 NaN
# Segmented                                              NaN
# Promyelocytes                                          NaN
# Metamyelocytes                                         NaN
# Myelocytes                                             NaN
# Myeloblasts                                            NaN
# Urine - Esterase                                       NaN
# Urine - Aspect                                         NaN
# Urine - pH                                             NaN
# Urine - Hemoglobin                                     NaN
# Urine - Bile pigments                                  NaN
# Urine - Ketone Bodies                                  NaN
# Urine - Nitrite                                        NaN
# Urine - Density                                        NaN
# Urine - Urobilinogen                                   NaN
# Urine - Protein                                        NaN
# Urine - Sugar                                          NaN
# Urine - Leukocytes                                     NaN
# Urine - Crystals                                       NaN
# Urine - Red blood cells                                NaN
# Urine - Hyaline cylinders                              NaN
# Urine - Granular cylinders                             NaN
# Urine - Yeasts                                         NaN
# Urine - Color                                          NaN
# Partial thromboplastin time (PTT)                      NaN
# Relationship (Patient/Normal)                          NaN
# International normalized ratio (INR)                   NaN
# Lactic Dehydrogenase                                   NaN
# Prothrombin time (PT), Activity                        NaN
# Vitamin B12                                            NaN
# Creatine phosphokinase (CPK)                           NaN
# Ferritin                                               NaN
# Arterial Lactic Acid                                   NaN
# Lipase dosage                                          NaN
# D-Dimer                                                NaN
# Albumin                                                NaN
# Hb saturation (arterial blood gases)                   NaN
# pCO2 (arterial blood gas analysis)                     NaN
# Base excess (arterial blood gas analysis)              NaN
# pH (arterial blood gas analysis)                       NaN
# Total CO2 (arterial blood gas analysis)                NaN
# HCO3 (arterial blood gas analysis)                     NaN
# pO2 (arterial blood gas analysis)                      NaN
# Arteiral Fio2                                          NaN
# Phosphor                                               NaN
# ctO2 (arterial blood gas analysis)                     NaN

# %%
breveDescricao(df)
# Out:
# O data set possui:
# - 106 atributos/campos; e
# - 5644 registros.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5644 entries, 0 to 5643
# Columns: 106 entries, Patient ID to ctO2 (arterial blood gas analysis)
# dtypes: float64(65), int64(4), object(37)
# memory usage: 4.6+ MB

# %%
df.drop("Patient ID", axis=1, inplace=True)
cardinalidade(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bdc64041a7b0> in <module>
# ----> 1 df.drop("Patient ID", axis==1, inplace=True)
#       2 cardinalidade(df)
#
# NameError: name 'axis' is not defined
