# %%
# Instruções basiconas de sempre.

# Lidar com dataframes.
import numpy as np
import pandas as pd

# Lidar com gráficos.
import matplotlib.pyplot as plt
import seaborn as sns
# import plotly
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from plotting import (multiple_histograms_plot,
                      bar_plot_with_categorical,
                      plot_confusion_matrix,
                      plot_confusion_matrix_2,
                      plot_roc)

# Lidar com preparação de dados.
from data_prep import data_prep as dp # Eu que fiz esse modulinho ("uuuuuuuuuma bosts!").
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (StandardScaler
                                   , MinMaxScaler)
from sklearn.model_selection import (train_test_split
                                     , cross_val_score
                                     , StratifiedKFold)

# Lidar com validação de modelos.
from sklearn.metrics import (confusion_matrix
                             , accuracy_score
                             , classification_report)

pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
#Bibliotecas necessárias para aquisitar as informações em json em requisitando uma API Rest.

import json
import requests

r = requests.get('https://brasil.io/api/dataset/gastos-deputados/cota_parlamentar/data?format=json')
if r.status_code == 200:
    json_gastos_parlamentares = json.loads(r.content)

# %% [markdown]
# # Transformando JSON em um DataFrame
# Seguindo as instruções em uma questão do [Stackoverflow](https://stackoverflow.com/questions/21104592/json-to-pandas-dataframe), temos:

# %%
df_gastos_parlamentares = pd.io.json.json_normalize(json_gastos_parlamentares["results"])
print(df_gastos_parlamentares.shape)
df_gastos_parlamentares.head()
# Out:
# (1000, 29)
#    codlegislatura datemissao  idecadastro  idedocumento  indtipodocumento  \
# 0  56              None       72442        0             0
# 1  56              None       66179        0             0
# 2  56              None       66828        0             0
# 3  56              None       67138        0             0
# 4  56              None       68720        0             0
#
#    nucarteiraparlamentar  nudeputadoid  nulegislatura  numano  \
# 0  145                    2924          2019           2019
# 1  282                    3163          2019           2019
# 2  355                    2917          2019           2019
# 3  113                    2320          2019           2019
# 4  175                    3240          2019           2019
#
#    numespecificacaosubcota  numlote  nummes  numparcela  numressarcimento  \
# 0  0                        0        7       0           0
# 1  0                        0        7       0           0
# 2  0                        0        7       0           0
# 3  0                        0        7       0           0
# 4  0                        0        7       0           0
#
#    numsubcota sgpartido sguf txnomeparlamentar      txtcnpjcpf txtdescricao  \
# 0  10          PSB       PE   FELIPE CARRERAS   00000000000006  TELEFONIA
# 1  10          DEM       ES   NORMA AYUB        00000000000006  TELEFONIA
# 2  10          PP        SP   FAUSTO PINATO     00000000000006  TELEFONIA
# 3  10          PP        PI   IRACEMA PORTELLA  00000000000006  TELEFONIA
# 4  10          PDT       SE   FÁBIO HENRIQUE    00000000000006  TELEFONIA
#
#   txtdescricaoespecificacao txtfornecedor txtnumero txtpassageiro txttrecho  \
# 0  None                      RAMAL         6900895   None          None
# 1  None                      RAMAL         6900895   None          None
# 2  None                      RAMAL         6900895   None          None
# 3  None                      RAMAL         6900895   None          None
# 4  None                      RAMAL         6900895   None          None
#
#   vlrdocumento vlrglosa vlrliquido vlrrestituicao
# 0  101.89       0.00     101.89     None
# 1  131.25       0.00     131.25     None
# 2  22.77        0.00     22.77      None
# 3  109.82       0.00     109.82     None
# 4  169.41       0.00     169.41     None

# %%
df_gastos_parlamentares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 29 columns):
# codlegislatura               1000 non-null int64
# datemissao                   0 non-null object
# idecadastro                  1000 non-null int64
# idedocumento                 1000 non-null int64
# indtipodocumento             1000 non-null int64
# nucarteiraparlamentar        1000 non-null int64
# nudeputadoid                 1000 non-null int64
# nulegislatura                1000 non-null int64
# numano                       1000 non-null int64
# numespecificacaosubcota      1000 non-null int64
# numlote                      1000 non-null int64
# nummes                       1000 non-null int64
# numparcela                   1000 non-null int64
# numressarcimento             1000 non-null int64
# numsubcota                   1000 non-null int64
# sgpartido                    1000 non-null object
# sguf                         1000 non-null object
# txnomeparlamentar            1000 non-null object
# txtcnpjcpf                   1000 non-null object
# txtdescricao                 1000 non-null object
# txtdescricaoespecificacao    0 non-null object
# txtfornecedor                1000 non-null object
# txtnumero                    1000 non-null object
# txtpassageiro                0 non-null object
# txttrecho                    0 non-null object
# vlrdocumento                 1000 non-null object
# vlrglosa                     1000 non-null object
# vlrliquido                   1000 non-null object
# vlrrestituicao               0 non-null object
# dtypes: int64(14), object(15)
# memory usage: 168.0+ KB

# %%
dp.serieNulos(df_gastos_parlamentares)
# Out:
# (vlrrestituicao               100.0
#  datemissao                   100.0
#  txttrecho                    100.0
#  txtpassageiro                100.0
#  txtdescricaoespecificacao    100.0
#  dtype: float64,
#  '-> 5 atributos/features/campos possuem mais de 50% de valores nulos.')

# %%
df_gastos_parlamentares.drop(["vlrrestituicao"
                              , "datemissao"
                              , "txttrecho"
                              , "txtpassageiro"
                              , "txtdescricaoespecificacao"], axis=1, inplace=True)

# %%
dp.cardinalidade(df_gastos_parlamentares)
# Out:
#             Atributo  Cardinalidade  \
# 3  txtcnpjcpf         1
# 4  txtdescricao       1
# 5  txtfornecedor      1
# 8  vlrglosa           1
# 6  txtnumero          2
# 0  sgpartido          27
# 1  sguf               27
# 2  txnomeparlamentar  517
# 7  vlrdocumento       977
# 9  vlrliquido         977
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Valores
# 3  [00000000000006]
# 4  [TELEFONIA]
# 5  [RAMAL]
# 8  [0.00]
# 6  [6900895, 6867342]
# 0  [PSB, DEM, PP, PDT, PODE, PT, PRB, CIDADANIA, PSOL, MDB, PCdoB, PL, PTB, PROS, PSDB, PSC, PSD, PSL, SOLIDARIEDADE, NOVO, AVANTE, PATRIOTA, PV, S.PART., REDE, PMN, PHS]
# 1  [PE, ES, SP, PI, SE, BA, PR, RS, MG, SC, RJ, AC, PB, PA, AM, MA, CE, GO, MS, RO, RN, TO, MT, RR, AL, DF, AP]
# 2  [FELIPE CARRERAS, NORMA AYUB, FAUSTO PINATO, IRACEMA PORTELLA, FÁBIO HENRIQUE, BACELAR, ARLINDO CHINAGLIA, CELSO RUSSOMANNO, GUSTAVO FRUET, RUBENS BUENO, HENRIQUE FONTANA, POMPEO DE MATTOS, IVAN VALENTE, JÚLIO DELGADO, ANGELA AMIN, RUI FALCÃO, BENEDITA DA SILVA, HERMES PARCIANELLO, RICARDO BARROS, RENILDO CALHEIROS, DARCÍSIO PERONDI, PERPÉTUA ALMEIDA, WELLINGTON ROBERTO, WILSON SANTIAGO, BOSCO COSTA, ALICE PORTUGAL, DANIEL ALMEIDA, ELCIONE BARBALHO, JOSÉ PRIANTE, ÁTILA LINS, LEONARDO MONTEIRO, MÁRIO HERINGER, ODAIR CUNHA, PATRUS ANANIAS, REGINAL
# 9  [101.89, 131.25, 22.77, 109.82, 169.41, 30.66, 112.37, 37.40, 16.65, 52.63, 82.48, 118.73, 56.53, 60.23, 77.64, 92.97, 57.88, 32.81, 94.32, 31.89, 154.46, 27.49, 136.41, 63.97, 58.72, 29.99, 168.94, 26.20, 87.45, 171.55, 152.90, 41.96, 25.60, 98.15, 75.88, 179.91, 250.56, 25.31, 10.95, 62.62, 131.90, 70.04, 198.35, 70.94, 33.50, 21.87, 133.74, 96.90, 226.96, 1.40, 185.12, 167.10, 33.79, 1.86, 8.77, 171.97, 36.20, 221.41, 130.19, 96.60, 74.78, 98.33, 133.57, 39.69, 75.72, 43.79, 77.35, 396.60, 109.42, 139.42, 60.09, 78.11, 63.68, 8.16, 49.50, 47.86, 184.52, 124.90, 32.77, 107.60, 231.28, 48.71, 111.07, 46.26, 66.68, 40.51, 106.72, 40.32, 130.73, 226.99, 15.18, 81.11, 45.59, 37.88, 139.57, 8.19, 4.33, 63.65, 128.20, 127.35, ...]

# %% [markdown]
# **Análise preliminar:**
#
# 1. Os atributos / fatores / variáveis independentes que possuem cardinalidade igual a um não oferecem nenhum ganho de informação. Atributos
# **Ação:** Remover esses atributos.
#
# 2. Os atributos vlrdocumento e vlrliquido estão como objects, mas são floats.
# **Ação:** Converter esses atributos para float.

# %%
# Removendo os atributos com cardinalidade <= 1:

lista_atributos_para_remover = list(dp.cardinalidade(df_gastos_parlamentares)[dp.cardinalidade(df_gastos_parlamentares)["Cardinalidade"] <= 1]["Atributo"].values)

df_gastos_parlamentares.drop(lista_atributos_para_remover, axis=1, inplace=True)

# %%
df_gastos_parlamentares.vlrdocumento = pd.to_numeric(df_gastos_parlamentares.vlrdocumento)
df_gastos_parlamentares.vlrliquido = pd.to_numeric(df_gastos_parlamentares.vlrliquido)

df_gastos_parlamentares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
# codlegislatura             1000 non-null int64
# idecadastro                1000 non-null int64
# idedocumento               1000 non-null int64
# indtipodocumento           1000 non-null int64
# nucarteiraparlamentar      1000 non-null int64
# nudeputadoid               1000 non-null int64
# nulegislatura              1000 non-null int64
# numano                     1000 non-null int64
# numespecificacaosubcota    1000 non-null int64
# numlote                    1000 non-null int64
# nummes                     1000 non-null int64
# numparcela                 1000 non-null int64
# numressarcimento           1000 non-null int64
# numsubcota                 1000 non-null int64
# sgpartido                  1000 non-null object
# sguf                       1000 non-null object
# txnomeparlamentar          1000 non-null object
# txtnumero                  1000 non-null object
# vlrdocumento               1000 non-null float64
# vlrliquido                 1000 non-null float64
# dtypes: float64(2), int64(14), object(4)
# memory usage: 140.7+ KB

# %%
dp.cardinalidade(df_gastos_parlamentares)
# Out:
#             Atributo  Cardinalidade  \
# 3  txtnumero          2
# 0  sgpartido          27
# 1  sguf               27
# 2  txnomeparlamentar  517
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      
# indtipodocumento         1000.0  0.00000       0.000000      0.00
# nucarteiraparlamentar    1000.0  268.07000     153.196522    1.00
# nudeputadoid             1000.0  2740.05400    773.332623    74.00
# nulegislatura            1000.0  2019.00000    0.000000      2019.00
# numano                   1000.0  2019.00000    0.000000      2019.00
# numespecificacaosubcota  1000.0  0.00000       0.000000      0.00
# numlote                  1000.0  0.00000       0.000000      0.00
# nummes                   1000.0  6.51500       0.500025      6.00
# numparcela               1000.0  0.00000       0.000000      0.00
# numressarcimento         1000.0  0.00000       0.000000      0.00
# numsubcota               1000.0  10.00000      0.000000      10.00
# vlrdocumento             1000.0  70.75479      62.324140     0.34
# vlrliquido               1000.0  70.75479      62.324140     0.34
#
#                                 25%        50%          75%       max
# codlegislatura           56.000      56.00      56.0000      56.0
# idecadastro              141523.000  178946.00  204441.2500  209189.0
# idedocumento             0.000       0.00       0.0000       0.0
# indtipodocumento         0.000       0.00       0.0000       0.0
# nucarteiraparlamentar    136.000     270.00     398.0000     542.0
# nudeputadoid             2275.000    3068.50    3311.0000    3452.0
# nulegislatura            2019.000    2019.00    2019.0000    2019.0
# numano                   2019.000    2019.00    2019.0000    2019.0
# numespecificacaosubcota  0.000       0.00       0.0000       0.0
# numlote                  0.000       0.00       0.0000       0.0
# nummes                   6.000       7.00       7.0000       7.0
# numparcela               0.000       0.00       0.0000       0.0
# numressarcimento         0.000       0.00       0.0000       0.0
# numsubcota               10.000      10.00      10.0000      10.0
# vlrdocumento             28.285      53.38      94.7725      518.2
# vlrliquido               28.285      53.38      94.7725      518.2

# %%
df_gastos_parlamentares.groupby(["sguf", "sgpartido"], axis=0)["vlrliquido"].mean()
# Out:
# sguf  sgpartido
# AC    DEM              50.955000
#       MDB              65.290000
#       PCdoB            38.580000
#       PDT              76.500000
#       PRB              45.150000
#       PSDB             69.590000
#       SOLIDARIEDADE    12.375000
# AL    MDB              223.525000
#       PL               46.545000
#       PP               59.745000
#       PRB              59.125000
#       PSB              11.105000
#       PSD              79.700000
#       PSDB             37.520000
#       PT               63.460000
#       PTB              54.620000
# AM    PL               47.010000
#       PP               149.465000
#       PRB              128.526667
#       PSD              34.030000
#       PSL              39.970000
#       PT               2.220000
#       SOLIDARIEDADE    35.050000
# AP    AVANTE           39.235000
#       PCdoB            22.635000
#       PL               68.235000
#       PP               23.500000
#       PRB              25.495000
#       PROS             11.985000
#       PSB              18.960000
#       PSDB             30.805000
# BA    AVANTE           121.365000
#       DEM              54.251250
#       PCdoB            97.092500
#       PDT              33.266667
#       PHS              21.770000
#       PL               106.947143
#       PODE             58.740000
#       PP               70.206250
#       PRB              65.623333
#       PROS             23.940000
#       PSB              92.097500
#       PSD              69.245000
#       PSDB             10.460000
#       PSL              63.100000
#       PT               50.124615
# CE    DEM              211.765000
#       MDB              106.490000
#       PDT              54.369000
#       PL               26.492500
#       PP               49.235000
#       PROS             10.920000
#       PSB              125.170000
#       PSD              81.210000
#       PSDB             182.515000
#       PSL              12.805000
#       PT               74.611667
#       PTB              192.110000
#       PV               32.445000
#       SOLIDARIEDADE    25.695000
# DF    CIDADANIA        23.250000
#       DEM              80.470000
#       PL               42.030000
#       PP               54.895000
#       PRB              36.780000
#       PSL              25.415000
#       PT               149.655000
#       PV               60.015000
# ES    CIDADANIA        60.215000
#       DEM              120.425000
#       PDT              196.940000
#       PL               102.200000
#       PP               137.490000
#       PRB              49.590000
#       PSB              44.306667
#       PSL              53.975000
#       PT               17.590000
# GO    DEM              304.077500
#       PATRIOTA         50.585000
#       PDT              216.365000
#       PL               19.585000
#       PODE             444.230000
#       PP               162.905000
#       PRB              161.845000
#       PSB              8.185000
#       PSC              256.975000
#       PSD              216.880000
#       PSDB             88.595000
#       PSL              52.340000
#       PT               155.495000
#       SOLIDARIEDADE    35.840000
# MA    DEM              9.095000
#       MDB              101.302500
#       PATRIOTA         116.260000
#       PCdoB            45.155000
#       PDT              40.060000
#       PL               23.803333
#       PMN              14.820000
#       PODE             58.885000
#       PP               11.555000
#       PRB              132.845000
#       PROS             170.185000
#       PSB              15.710000
#       PSD              79.060000
#       PT               30.785000
#       PTB              72.155000
# MG    AVANTE           35.528333
#       DEM              220.190000
#       MDB              182.517143
#       NOVO             32.722500
#       PATRIOTA         66.020000
#       PDT              58.550000
#       PL               90.080000
#       PODE             170.515000
#       PP               62.712500
#       PRB              83.940000
#       PROS             74.665000
#       PSB              43.410000
#       PSC              90.040000
#       PSD              116.130000
#       PSDB             220.624000
#       PSL              83.970833
#       PSOL             19.110000
#       PT               66.146875
#       SOLIDARIEDADE    174.155000
# MS    DEM              5.890000
#       PDT              52.430000
#       PSD              9.520000
#       PSDB             56.291667
#       PSL              90.750000
#       PT               209.460000
# MT    MDB              73.532500
#       PODE             158.985000
#       PP               68.015000
#       PSL              88.830000
#       PT               57.010000
#       PTB              177.490000
#       SOLIDARIEDADE    79.570000
# PA    DEM              58.565000
#       MDB              54.247500
#       PL               63.500000
#       PRB              19.315000
#       PSB              22.160000
#       PSD              52.840000
#       PSDB             23.967500
#       PSOL             6.045000
#       PT               53.782500
#       PTB              69.640000
# PB    DEM              44.695000
#       PDT              141.730000
#       PL               131.420000
#       PP               22.870000
#       PRB              30.705000
#       PSB              28.935000
#       PSDB             61.971667
#       PSL              29.410000
#       PT               122.390000
#       PTB              46.105000
# PE    CIDADANIA        47.520000
#       DEM              41.505000
#       MDB              91.770000
#       PATRIOTA         105.205000
#       PCdoB            23.755000
#       PDT              55.840000
#       PL               75.190000
#       PODE             24.345000
#       PP               21.495000
#       PRB              85.527500
#       PSB              70.550000
#       PSC              37.085000
#       PSD              63.670000
#       PSL              58.510000
#       PT               24.950000
#       SOLIDARIEDADE    196.790000
# PI    MDB              3.460000
#       PDT              38.270000
#       PP               78.660000
#       PSB              190.140000
#       PSD              60.750000
#       PT               23.634000
#       PTB              23.065000
#       SOLIDARIEDADE    13.770000
# PR    CIDADANIA        53.045000
#       DEM              93.185000
#       MDB              65.007500
#       PDT              14.005000
#       PL               69.961667
#       PODE             94.905000
#       PP               79.032500
#       PRB              146.117500
#       PROS             177.482500
#       PSB              40.580000
#       PSC              64.485000
#       PSD              146.425714
#       PSL              24.140000
#       PT               73.395000
#       PTB              90.310000
#       PV               48.235000
# RJ    AVANTE           34.325000
#       CIDADANIA        54.485000
#       DEM              52.093750
#       MDB              63.180000
#       NOVO             12.720000
#       PCdoB            72.945000
#       PDT              21.700000
#       PL               43.253333
#       PP               153.640000
#       PRB              35.123333
#       PROS             6.970000
#       PSB              63.965000
#       PSC              35.555000
#       PSD              41.222500
#       PSL              35.886250
#       PSOL             31.478571
#       PT               52.845000
#       S.PART.          183.395000
#       SOLIDARIEDADE    109.005000
# RN    MDB              64.635000
#       PL               130.995000
#       PP               69.185000
#       PRB              37.620000
#       PSB              42.150000
#       PSD              74.425000
#       PSL              5.125000
#       PT               5.250000
# RO    MDB              63.885000
#       PDT              35.190000
#       PODE             81.915000
#       PP               101.885000
#       PSB              41.430000
#       PSD              25.210000
#       PSDB             31.960000
#       PSL              54.910000
# RR    PL               92.200000
#       PP               94.135000
#       PRB              13.180000
#       PSD              26.995000
#       PSDB             47.430000
#       PSL              29.780000
#       REDE             5.020000
#       SOLIDARIEDADE    65.360000
# RS    DEM              1.860000
#       MDB              75.966250
#       NOVO             67.485000
#       PDT              56.348333
#       PL               95.670000
#       PP               99.283333
#       PRB              44.925000
#       PSB              33.380000
#       PSD              86.735000
#       PSDB             56.792500
#       PSL              115.458571
#       PSOL             10.420000
#       PT               45.918000
#       PTB              99.761667
# SC    CIDADANIA        133.365000
#       MDB              43.821667
#       NOVO             15.115000
#       PP               59.335000
#       PRB              63.735000
#       PSB              9.900000
#       PSD              78.312500
#       PSDB             101.230000
#       PSL              27.036250
#       PT               44.195000
# SE    MDB              80.550000
#       PDT              165.910000
#       PL               65.130000
#       PP               50.410000
#       PSC              37.685000
#       PSD              89.250000
#       PT               37.195000
#       SOLIDARIEDADE    15.910000
# SP    CIDADANIA        135.215000
#       DEM              55.896000
#       MDB              106.992500
#       NOVO             23.088333
#       PCdoB            91.625000
#       PDT              8.820000
#       PL               52.392857
#       PODE             58.716667
#       PP               71.568750
#       PRB              50.305000
#       PSB              56.777500
#       PSC              26.835000
#       PSD              92.785000
#       PSDB             93.394167
#       PSL              60.925500
#       PSOL             44.975000
#       PT               77.339375
#       PV               75.820000
#       SOLIDARIEDADE    104.140000
# TO    DEM              80.597500
#       MDB              52.700000
#       PL               124.390000
#       PSC              35.390000
#       PT               27.895000
#       SOLIDARIEDADE    32.647500
# Name: vlrliquido, dtype: float64
