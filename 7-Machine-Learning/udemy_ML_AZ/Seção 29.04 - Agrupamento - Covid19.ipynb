# %% [markdown]
# # Seção 29.04 - Agrupamento - Covid19
# Este notebook usa dados disponibilizados pelo Einstein Data4u: [Diagnosis of COVID-19 and its clinical spectrum](https://www.kaggle.com/dataset/e626783d4672f182e7870b1bbe75fae66bdfb232289da0a61f08c2ceb01cab01).
#
# As tasks descritas no link supracitado são em suma:
# 1. Prever os casos confirmados de Covid-19 (resposta/target/classe: **SARS-Cov-2 exam result**) entre os casos suspeitos; e
# 2. Prever a admissão na enfermaria geral, unidade semi-intensiva ou unidade de terapia intensiva entre os casos confirmados de Covid-19.

# %% [markdown]
# ## O que verei nesse notebook:
# O aprendizado deste notebook está pautado em 3 pilares/assuntos:
# 1. CRISP-DM;
# 2. Modelos de agrupamento (K-means, DB-Scan etc.); e
# 3. Modelos de classificação (Árvores de decisão, Random forests, Gradient boosting etc.)

# %% [markdown]
# ## CRISP-DM:
#
# <tr>
#     <td>
#         <img src="./imagens/crisp.png" alt="CRISP-DM" width="350"/>
#         <p style="text-align:center">Figura 01 - Esquema de CRISP-DM.</p>
#         <p style="text-align:center">Fonte: 2017; Vasconcellos, P., A. L.; CRISP-DM, SEMMA e KDD: conheça as melhores técnicas para exploração de dados</p>
#     </td>
# </tr>
#
# Referências:
# - 2017; Vasconcellos, P., A. L.; [CRISP-DM, SEMMA e KDD: conheça as melhores técnicas para exploração de dados](https://paulovasconcellos.com.br/crisp-dm-semma-e-kdd-conhe%C3%A7a-as-melhores-t%C3%A9cnicas-para-explora%C3%A7%C3%A3o-de-dados-560d294547d2)
# - 2018; Vaz, A. L.; [Gerenciamento de Projetos de Data Science com CRISP](https://medium.com/data-hackers/project-data-science-pds-39d5a78e058a)

# %% [markdown]
# Para o caso em questão, temos um problema bem direto e podemos sem cautela pular a etapa de **BUSINESS UNDERSTANDING** e passar para a etpa de **DATA UNDERSTANDING**.
#
# ## Data understanding
#
# Pegando a primeira task proposta pelo Einstein Data4U **(1. Prever os casos confirmados de Covid-19 entre os casos suspeitos**. Podemos formular perguntas para nos ajudar na etapa de **DATA UNDERSTANDING** da task 1.
# 1. Quantos registros temos no dataset?
# 2. Qual a proporção de confirmados de Covid-19?
# 3. Quantos atributos temos? Quantos são totalmente nulos? Qual a cardinalidade do resto?
# 4. É possível identificar agrupamentos?

# %%
import numpy as np
import pandas as pd

# Lidar com gráficos.
import matplotlib.pyplot as plt
import seaborn as sns
# import plotly
from bokeh.plotting import figure
from bokeh.io import show, output_notebook

# Lidar com preparação de dados.
from data_prep import data_prep as dp # Eu que fiz esse modulinho ("uuuuuuuuuma bosts!").
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (StandardScaler
                                   , MinMaxScaler)
from sklearn.model_selection import (train_test_split
                                     , cross_val_score
                                     , StratifiedKFold)

# Lidar com validação de modelos.
from sklearn.metrics import (confusion_matrix
                             , accuracy_score
                             , classification_report)

pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 500)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-6db18b99dc0a> in <module>
#       3
#       4 # Lidar com gráficos.
# ----> 5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
#       7 # import plotly
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in <module>
#      31 import matplotlib
#      32 import matplotlib.colorbar
# ---> 33 import matplotlib.image
#      34 from matplotlib import rcsetup, style
#      35 from matplotlib import _pylab_helpers, interactive
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in <module>
#      15 from matplotlib import rcParams
#      16 import matplotlib.artist as martist
# ---> 17 from matplotlib.backend_bases import FigureCanvasBase
#      18 import matplotlib.colors as mcolors
#      19 import matplotlib.cm as cm
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in <module>
#    1563
#    1564
# -> 1565 class FigureCanvasBase:
#    1566     """
#    1567     The canvas the figure renders into.
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in FigureCanvasBase()
#    1612                          'Tagged Image File Format')
#    1613
# -> 1614     @cbook._classproperty
#    1615     def supports_blit(cls):
#    1616         return (hasattr(cls, "copy_from_bbox")
#
# AttributeError: module 'matplotlib.cbook' has no attribute '_classproperty'

# %%
# # Input data files are available in the "../input/" directory.
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # Any results you write to the current directory are saved as output.

# %%
df = pd.read_excel("../bases/dataset_covid_hospital_einstein.xlsx")
df.shape
# Out:
# (5644, 111)

# %%
df_proporcao_covid19 = pd.DataFrame(round(100*df["SARS-Cov-2 exam result"].value_counts()/len(df), 2))
df_proporcao_covid19
# Out:
#           SARS-Cov-2 exam result
# negative                   90.11
# positive                    9.89

# %%
dp.breveDescricao(df)
# Out:
# O data set possui:
# - 106 atributos/campos; e
# - 5644 registros.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5644 entries, 0 to 5643
# Columns: 106 entries, Patient ID to ctO2 (arterial blood gas analysis)
# dtypes: float64(65), int64(4), object(37)
# memory usage: 4.6+ MB

# %% [markdown]
# # Definindo um baseline
# Tendo em vista que a **task 1** é um problema de classificação, vamos pegar um modelo robusto a uma base de dados com falhas (registros nulos nesse caso) e ver como ele se sai antes de qualquer engenharia de atributos (feature engineering).
#
# ## Sem nenhuma engenharia de atributos
# Como os dados para a árvore de decisão deve ser numéricos, vou proceder da seguinte forma:
# - Num primeiro momento, aplicarei a árvore somente com os atributos numéricos;
# - Na seção posterior, executarei alguma transformação nos dados categóricos, como One Hot Encoding, juntarei com os dados numéricos e aplicarei a árvore novamente.

# %% [markdown]
# ### Aplicação usando somente os atributos numéricos:

# %%
df["SARS-Cov-2 exam result - Numerico"] = np.where(df["SARS-Cov-2 exam result"]=="positive", 1, 0)
df_numericos = df.select_dtypes(exclude=["object"])

# Simplesmente preencheremos os nan com zeros, o que faz sentido.
df_numericos.fillna(0, inplace=True)

x = df_numericos.drop("SARS-Cov-2 exam result - Numerico", axis=1)
y = df_numericos["SARS-Cov-2 exam result - Numerico"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=0)
# Out:
# C:\Users\gusta\anaconda3\lib\site-packages\pandas\core\frame.py:4153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
df_numericos[df_numericos["SARS-Cov-2 exam result - Numerico"]==1].sample(7, random_state=0).T
# Out:
#                                                        3261  5077  5086  5302  \
# Patient age quantile                                   13.0   5.0   3.0   3.0
# Patient addmited to regular ward (1=yes, 0=no)          0.0   0.0   0.0   0.0
# Patient addmited to semi-intensive unit (1=yes, 0=no)   0.0   0.0   0.0   0.0
# Patient addmited to intensive care unit (1=yes, 0=no)   0.0   0.0   0.0   0.0
# Hematocrit                                              0.0   0.0   0.0   0.0
# Hemoglobin                                              0.0   0.0   0.0   0.0
# Platelets                                               0.0   0.0   0.0   0.0
# Mean platelet volume                                    0.0   0.0   0.0   0.0
# Red blood Cells                                         0.0   0.0   0.0   0.0
# Lymphocytes                                             0.0   0.0   0.0   0.0
# Mean corpuscular hemoglobin concentration (MCHC)        0.0   0.0   0.0   0.0
# Leukocytes                                              0.0   0.0   0.0   0.0
# Basophils                                               0.0   0.0   0.0   0.0
# Mean corpuscular hemoglobin (MCH)                       0.0   0.0   0.0   0.0
# Eosinophils                                             0.0   0.0   0.0   0.0
# Mean corpuscular volume (MCV)                           0.0   0.0   0.0   0.0
# Monocytes                                               0.0   0.0   0.0   0.0
# Red blood cell distribution width (RDW)                 0.0   0.0   0.0   0.0
# Serum Glucose                                           0.0   0.0   0.0   0.0
# Neutrophils                                             0.0   0.0   0.0   0.0
# Urea                                                    0.0   0.0   0.0   0.0
# Proteina C reativa mg/dL                                0.0   0.0   0.0   0.0
# Creatinine                                              0.0   0.0   0.0   0.0
# Potassium                                               0.0   0.0   0.0   0.0
# Sodium                                                  0.0   0.0   0.0   0.0
# Alanine transaminase                                    0.0   0.0   0.0   0.0
# Aspartate transaminase                                  0.0   0.0   0.0   0.0
# Gamma-glutamyltransferase                               0.0   0.0   0.0   0.0
# Total Bilirubin                                         0.0   0.0   0.0   0.0
# Direct Bilirubin                                        0.0   0.0   0.0   0.0
# Indirect Bilirubin                                      0.0   0.0   0.0   0.0
# Alkaline phosphatase                                    0.0   0.0   0.0   0.0
# Ionized calcium                                         0.0   0.0   0.0   0.0
# Magnesium                                               0.0   0.0   0.0   0.0
# pCO2 (venous blood gas analysis)                        0.0   0.0   0.0   0.0
# Hb saturation (venous blood gas analysis)               0.0   0.0   0.0   0.0
# Base excess (venous blood gas analysis)                 0.0   0.0   0.0   0.0
# pO2 (venous blood gas analysis)                         0.0   0.0   0.0   0.0
# Fio2 (venous blood gas analysis)                        0.0   0.0   0.0   0.0
# Total CO2 (venous blood gas analysis)                   0.0   0.0   0.0   0.0
# pH (venous blood gas analysis)                          0.0   0.0   0.0   0.0
# HCO3 (venous blood gas analysis)                        0.0   0.0   0.0   0.0
# Rods #                                                  0.0   0.0   0.0   0.0
# Segmented                                               0.0   0.0   0.0   0.0
# Promyelocytes                                           0.0   0.0   0.0   0.0
# Metamyelocytes                                          0.0   0.0   0.0   0.0
# Myelocytes                                              0.0   0.0   0.0   0.0
# Myeloblasts                                             0.0   0.0   0.0   0.0
# Urine - Density                                         0.0   0.0   0.0   0.0
# Urine - Red blood cells                                 0.0   0.0   0.0   0.0
# Relationship (Patient/Normal)                           0.0   0.0   0.0   0.0
# International normalized ratio (INR)                    0.0   0.0   0.0   0.0
# Lactic Dehydrogenase                                    0.0   0.0   0.0   0.0
# Vitamin B12                                             0.0   0.0   0.0   0.0
# Creatine phosphokinase (CPK)                            0.0   0.0   0.0   0.0
# Ferritin                                                0.0   0.0   0.0   0.0
# Arterial Lactic Acid                                    0.0   0.0   0.0   0.0
# Lipase dosage                                           0.0   0.0   0.0   0.0
# Albumin                                                 0.0   0.0   0.0   0.0
# Hb saturation (arterial blood gases)                    0.0   0.0   0.0   0.0
# pCO2 (arterial blood gas analysis)                      0.0   0.0   0.0   0.0
# Base excess (arterial blood gas analysis)               0.0   0.0   0.0   0.0
# pH (arterial blood gas analysis)                        0.0   0.0   0.0   0.0
# Total CO2 (arterial blood gas analysis)                 0.0   0.0   0.0   0.0
# HCO3 (arterial blood gas analysis)                      0.0   0.0   0.0   0.0
# pO2 (arterial blood gas analysis)                       0.0   0.0   0.0   0.0
# Arteiral Fio2                                           0.0   0.0   0.0   0.0
# Phosphor                                                0.0   0.0   0.0   0.0
# ctO2 (arterial blood gas analysis)                      0.0   0.0   0.0   0.0
# SARS-Cov-2 exam result - Numerico                       1.0   1.0   1.0   1.0
#
#                                                        5444  2237  1432
# Patient age quantile                                    3.0  13.0  11.0
# Patient addmited to regular ward (1=yes, 0=no)          0.0   0.0   0.0
# Patient addmited to semi-intensive unit (1=yes, 0=no)   0.0   0.0   0.0
# Patient addmited to intensive care unit (1=yes, 0=no)   0.0   0.0   0.0
# Hematocrit                                              0.0   0.0   0.0
# Hemoglobin                                              0.0   0.0   0.0
# Platelets                                               0.0   0.0   0.0
# Mean platelet volume                                    0.0   0.0   0.0
# Red blood Cells                                         0.0   0.0   0.0
# Lymphocytes                                             0.0   0.0   0.0
# Mean corpuscular hemoglobin concentration (MCHC)        0.0   0.0   0.0
# Leukocytes                                              0.0   0.0   0.0
# Basophils                                               0.0   0.0   0.0
# Mean corpuscular hemoglobin (MCH)                       0.0   0.0   0.0
# Eosinophils                                             0.0   0.0   0.0
# Mean corpuscular volume (MCV)                           0.0   0.0   0.0
# Monocytes                                               0.0   0.0   0.0
# Red blood cell distribution width (RDW)                 0.0   0.0   0.0
# Serum Glucose                                           0.0   0.0   0.0
# Neutrophils                                             0.0   0.0   0.0
# Urea                                                    0.0   0.0   0.0
# Proteina C reativa mg/dL                                0.0   0.0   0.0
# Creatinine                                              0.0   0.0   0.0
# Potassium                                               0.0   0.0   0.0
# Sodium                                                  0.0   0.0   0.0
# Alanine transaminase                                    0.0   0.0   0.0
# Aspartate transaminase                                  0.0   0.0   0.0
# Gamma-glutamyltransferase                               0.0   0.0   0.0
# Total Bilirubin                                         0.0   0.0   0.0
# Direct Bilirubin                                        0.0   0.0   0.0
# Indirect Bilirubin                                      0.0   0.0   0.0
# Alkaline phosphatase                                    0.0   0.0   0.0
# Ionized calcium                                         0.0   0.0   0.0
# Magnesium                                               0.0   0.0   0.0
# pCO2 (venous blood gas analysis)                        0.0   0.0   0.0
# Hb saturation (venous blood gas analysis)               0.0   0.0   0.0
# Base excess (venous blood gas analysis)                 0.0   0.0   0.0
# pO2 (venous blood gas analysis)                         0.0   0.0   0.0
# Fio2 (venous blood gas analysis)                        0.0   0.0   0.0
# Total CO2 (venous blood gas analysis)                   0.0   0.0   0.0
# pH (venous blood gas analysis)                          0.0   0.0   0.0
# HCO3 (venous blood gas analysis)                        0.0   0.0   0.0
# Rods #                                                  0.0   0.0   0.0
# Segmented                                               0.0   0.0   0.0
# Promyelocytes                                           0.0   0.0   0.0
# Metamyelocytes                                          0.0   0.0   0.0
# Myelocytes                                              0.0   0.0   0.0
# Myeloblasts                                             0.0   0.0   0.0
# Urine - Density                                         0.0   0.0   0.0
# Urine - Red blood cells                                 0.0   0.0   0.0
# Relationship (Patient/Normal)                           0.0   0.0   0.0
# International normalized ratio (INR)                    0.0   0.0   0.0
# Lactic Dehydrogenase                                    0.0   0.0   0.0
# Vitamin B12                                             0.0   0.0   0.0
# Creatine phosphokinase (CPK)                            0.0   0.0   0.0
# Ferritin                                                0.0   0.0   0.0
# Arterial Lactic Acid                                    0.0   0.0   0.0
# Lipase dosage                                           0.0   0.0   0.0
# Albumin                                                 0.0   0.0   0.0
# Hb saturation (arterial blood gases)                    0.0   0.0   0.0
# pCO2 (arterial blood gas analysis)                      0.0   0.0   0.0
# Base excess (arterial blood gas analysis)               0.0   0.0   0.0
# pH (arterial blood gas analysis)                        0.0   0.0   0.0
# Total CO2 (arterial blood gas analysis)                 0.0   0.0   0.0
# HCO3 (arterial blood gas analysis)                      0.0   0.0   0.0
# pO2 (arterial blood gas analysis)                       0.0   0.0   0.0
# Arteiral Fio2                                           0.0   0.0   0.0
# Phosphor                                                0.0   0.0   0.0
# ctO2 (arterial blood gas analysis)                      0.0   0.0   0.0
# SARS-Cov-2 exam result - Numerico                       1.0   1.0   1.0

# %%
#verificando se a proporção de classes se manteve após o split:

print("Negativos: {:.2f}".format(100*len(y_test[y_test==0])/len(y_test)))
print("Positivos: {:.2f}".format(100*len(y_test[y_test==1])/len(y_test)))
# Out:
# Negativos: 90.29
# Positivos: 9.71

# %% [markdown]
# #### Árvore de decisão

# %%
from sklearn.tree import (DecisionTreeClassifier
                          , export)

# classificador = DecisionTreeClassifier(criterion='entropy', random_state=0, max_depth=(len(x.columns)**0.5)*2)
classificador = DecisionTreeClassifier(criterion='entropy'
                                       , random_state=0
                                       , max_depth=len(x_train.columns)**0.5)

classificador.fit(x_train, y_train)

y_pred = classificador.predict(x_test)

# %%
print("""Métrica 1 (Relatório de classificação): {}""".format(classification_report(y_test
                                                                                    , y_pred
                                                                                    , target_names=["negative", "positive"])))
# Out:
# Métrica 1 (Relatório de classificação):               precision    recall  f1-score   support
#
#     negative       0.91      1.00      0.95      2548
#     positive       0.52      0.05      0.09       274
#
#     accuracy                           0.90      2822
#    macro avg       0.71      0.52      0.52      2822
# weighted avg       0.87      0.90      0.87      2822

# %%
feature_importance = pd.DataFrame(data=(classificador.feature_importances_).reshape(1,len(x_train.columns))
                                  , columns=x_train.columns)

feature_importance = feature_importance.T

feature_importance.sort_values(by=0, ascending=False)
# Out:
#                                                               0
# Patient age quantile                                   0.318972
# Patient addmited to regular ward (1=yes, 0=no)         0.140942
# Leukocytes                                             0.131215
# pO2 (arterial blood gas analysis)                      0.079572
# Red blood Cells                                        0.064274
# Eosinophils                                            0.054602
# Alanine transaminase                                   0.046001
# Platelets                                              0.042951
# Mean platelet volume                                   0.034985
# Urea                                                   0.030874
# Total CO2 (venous blood gas analysis)                  0.021733
# pCO2 (arterial blood gas analysis)                     0.018040
# Hemoglobin                                             0.011763
# Hb saturation (venous blood gas analysis)              0.003773
# Hematocrit                                             0.000105
# Patient addmited to intensive care unit (1=yes, 0=no)  0.000067
# Patient addmited to semi-intensive unit (1=yes, 0=no)  0.000066
# Metamyelocytes                                         0.000066
# Myelocytes                                             0.000000
# Vitamin B12                                            0.000000
# Promyelocytes                                          0.000000
# Myeloblasts                                            0.000000
# Urine - Density                                        0.000000
# Urine - Red blood cells                                0.000000
# Relationship (Patient/Normal)                          0.000000
# International normalized ratio (INR)                   0.000000
# Lactic Dehydrogenase                                   0.000000
# Arteiral Fio2                                          0.000000
# Creatine phosphokinase (CPK)                           0.000000
# Phosphor                                               0.000000
# Ferritin                                               0.000000
# Arterial Lactic Acid                                   0.000000
# Lipase dosage                                          0.000000
# Albumin                                                0.000000
# Rods #                                                 0.000000
# Hb saturation (arterial blood gases)                   0.000000
# Base excess (arterial blood gas analysis)              0.000000
# pH (arterial blood gas analysis)                       0.000000
# Total CO2 (arterial blood gas analysis)                0.000000
# HCO3 (arterial blood gas analysis)                     0.000000
# Segmented                                              0.000000
# pCO2 (venous blood gas analysis)                       0.000000
# HCO3 (venous blood gas analysis)                       0.000000
# Potassium                                              0.000000
# Lymphocytes                                            0.000000
# Mean corpuscular hemoglobin concentration (MCHC)       0.000000
# Basophils                                              0.000000
# Mean corpuscular hemoglobin (MCH)                      0.000000
# Mean corpuscular volume (MCV)                          0.000000
# Monocytes                                              0.000000
# Red blood cell distribution width (RDW)                0.000000
# Serum Glucose                                          0.000000
# Neutrophils                                            0.000000
# Proteina C reativa mg/dL                               0.000000
# Creatinine                                             0.000000
# Sodium                                                 0.000000
# pH (venous blood gas analysis)                         0.000000
# Aspartate transaminase                                 0.000000
# Gamma-glutamyltransferase                              0.000000
# Total Bilirubin                                        0.000000
# Direct Bilirubin                                       0.000000
# Indirect Bilirubin                                     0.000000
# Alkaline phosphatase                                   0.000000
# Ionized calcium                                        0.000000
# Magnesium                                              0.000000
# Base excess (venous blood gas analysis)                0.000000
# pO2 (venous blood gas analysis)                        0.000000
# Fio2 (venous blood gas analysis)                       0.000000
# ctO2 (arterial blood gas analysis)                     0.000000

# %% [markdown]
# #### Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

classificador = RandomForestClassifier(n_estimators=100
                                       , criterion='entropy'
                                       , random_state=0
                                       , max_depth=len(x_train.columns)**0.5)

classificador.fit(x_train, y_train)

y_pred = classificador.predict(x_test)

# %%
print("Métrica 1 (Relatório de classificação):\n{}\n".format(classification_report(y_test
                                                                                   , y_pred
                                                                                   , target_names=["negative", "positive"]
                                                                                  )))
# Out:
# Métrica 1 (Relatório de classificação):
#               precision    recall  f1-score   support
#
#     negative       0.90      1.00      0.95      2548
#     positive       0.67      0.01      0.03       274
#
#     accuracy                           0.90      2822
#    macro avg       0.79      0.51      0.49      2822
# weighted avg       0.88      0.90      0.86      2822

# %%
feature_importance = pd.DataFrame(data=(classificador.feature_importances_).reshape(1,len(x_train.columns))
                                  , columns=x_train.columns)

feature_importance = feature_importance.T

feature_importance.sort_values(by=0, ascending=False)
# Out:
#                                                               0
# Patient age quantile                                   0.167211
# Leukocytes                                             0.081495
# Platelets                                              0.058368
# Patient addmited to regular ward (1=yes, 0=no)         0.055526
# Monocytes                                              0.034270
# Eosinophils                                            0.032862
# Mean corpuscular volume (MCV)                          0.028207
# Proteina C reativa mg/dL                               0.027973
# Lymphocytes                                            0.025843
# Aspartate transaminase                                 0.022913
# Gamma-glutamyltransferase                              0.022721
# Red blood Cells                                        0.022117
# pCO2 (arterial blood gas analysis)                     0.021967
# Hemoglobin                                             0.020552
# Mean platelet volume                                   0.019631
# Arterial Lactic Acid                                   0.018761
# Creatinine                                             0.018739
# Neutrophils                                            0.017411
# Hematocrit                                             0.017303
# Red blood cell distribution width (RDW)                0.015845
# Urea                                                   0.014523
# Alanine transaminase                                   0.014502
# Mean corpuscular hemoglobin (MCH)                      0.013253
# pO2 (arterial blood gas analysis)                      0.011956
# Base excess (arterial blood gas analysis)              0.011714
# ctO2 (arterial blood gas analysis)                     0.011017
# Sodium                                                 0.011014
# Mean corpuscular hemoglobin concentration (MCHC)       0.010276
# Total Bilirubin                                        0.010135
# pH (venous blood gas analysis)                         0.010107
# Basophils                                              0.009932
# Lactic Dehydrogenase                                   0.009335
# HCO3 (arterial blood gas analysis)                     0.009069
# Potassium                                              0.008611
# Serum Glucose                                          0.007881
# Indirect Bilirubin                                     0.007737
# Relationship (Patient/Normal)                          0.007436
# Alkaline phosphatase                                   0.006088
# Hb saturation (arterial blood gases)                   0.005547
# Urine - Density                                        0.005385
# Total CO2 (arterial blood gas analysis)                0.005363
# Direct Bilirubin                                       0.004928
# Base excess (venous blood gas analysis)                0.004924
# pH (arterial blood gas analysis)                       0.004606
# Myelocytes                                             0.004513
# Total CO2 (venous blood gas analysis)                  0.004485
# Promyelocytes                                          0.004308
# Hb saturation (venous blood gas analysis)              0.004102
# International normalized ratio (INR)                   0.003989
# Creatine phosphokinase (CPK)                           0.003826
# Ionized calcium                                        0.003756
# pCO2 (venous blood gas analysis)                       0.003153
# pO2 (venous blood gas analysis)                        0.002883
# Urine - Red blood cells                                0.002763
# Segmented                                              0.002371
# HCO3 (venous blood gas analysis)                       0.002333
# Magnesium                                              0.002140
# Metamyelocytes                                         0.002013
# Patient addmited to intensive care unit (1=yes, 0=no)  0.001747
# Arteiral Fio2                                          0.001355
# Ferritin                                               0.001272
# Lipase dosage                                          0.001219
# Patient addmited to semi-intensive unit (1=yes, 0=no)  0.000890
# Rods #                                                 0.000804
# Phosphor                                               0.000532
# Albumin                                                0.000493
# Vitamin B12                                            0.000000
# Fio2 (venous blood gas analysis)                       0.000000
# Myeloblasts                                            0.000000

# %% [markdown]
# #### Análise preliminar
# Somente com os atributos numéricos alcançamos míseros 0,01 para o recall da classe positiva. Em outras palavras, apenas 1% dos casos de Covid-19 estão sendo detectados. **Mas temos o mais importante: um baseline**.
#
# **Saída:** Vamos passar os atributos categóricos por tratamentos e por engenharia de atributos (feature engineering) para melhorar nosso modelo.

# %% [markdown]
# ### Engenharia de atributos sobre as variáveis categóricas

# %%
df_categoricas = df.select_dtypes(include=["object"])
df_categoricas["SARS-Cov-2 exam result - Numerico"] = df.loc[:,("SARS-Cov-2 exam result - Numerico")].values
df_categoricas.sample(5, random_state=42).T
# Out:
# C:\Users\gusta\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                               1694             4434  \
# Patient ID                         5541f42a107f084  d312238aa508c24
# SARS-Cov-2 exam result                    negative         negative
# Respiratory Syncytial Virus                    NaN              NaN
# Influenza A                                    NaN              NaN
# Influenza B                                    NaN              NaN
# Parainfluenza 1                                NaN              NaN
# CoronavirusNL63                                NaN              NaN
# Rhinovirus/Enterovirus                         NaN              NaN
# Coronavirus HKU1                               NaN              NaN
# Parainfluenza 3                                NaN              NaN
# Chlamydophila pneumoniae                       NaN              NaN
# Adenovirus                                     NaN              NaN
# Parainfluenza 4                                NaN              NaN
# Coronavirus229E                                NaN              NaN
# CoronavirusOC43                                NaN              NaN
# Inf A H1N1 2009                                NaN              NaN
# Bordetella pertussis                           NaN              NaN
# Metapneumovirus                                NaN              NaN
# Parainfluenza 2                                NaN              NaN
# Influenza B, rapid test                        NaN              NaN
# Influenza A, rapid test                        NaN              NaN
# Strepto A                                      NaN         positive
# Urine - Esterase                               NaN              NaN
# Urine - Aspect                                 NaN              NaN
# Urine - pH                                     NaN              NaN
# Urine - Hemoglobin                             NaN              NaN
# Urine - Bile pigments                          NaN              NaN
# Urine - Ketone Bodies                          NaN              NaN
# Urine - Nitrite                                NaN              NaN
# Urine - Urobilinogen                           NaN              NaN
# Urine - Protein                                NaN              NaN
# Urine - Leukocytes                             NaN              NaN
# Urine - Crystals                               NaN              NaN
# Urine - Hyaline cylinders                      NaN              NaN
# Urine - Granular cylinders                     NaN              NaN
# Urine - Yeasts                                 NaN              NaN
# Urine - Color                                  NaN              NaN
# SARS-Cov-2 exam result - Numerico                0                0
#
#                                               3297             3980  \
# Patient ID                         23b19225d2fdd4c  63aeba2b01cb895
# SARS-Cov-2 exam result                    negative         negative
# Respiratory Syncytial Virus                    NaN              NaN
# Influenza A                                    NaN              NaN
# Influenza B                                    NaN              NaN
# Parainfluenza 1                                NaN              NaN
# CoronavirusNL63                                NaN              NaN
# Rhinovirus/Enterovirus                         NaN              NaN
# Coronavirus HKU1                               NaN              NaN
# Parainfluenza 3                                NaN              NaN
# Chlamydophila pneumoniae                       NaN              NaN
# Adenovirus                                     NaN              NaN
# Parainfluenza 4                                NaN              NaN
# Coronavirus229E                                NaN              NaN
# CoronavirusOC43                                NaN              NaN
# Inf A H1N1 2009                                NaN              NaN
# Bordetella pertussis                           NaN              NaN
# Metapneumovirus                                NaN              NaN
# Parainfluenza 2                                NaN              NaN
# Influenza B, rapid test                        NaN              NaN
# Influenza A, rapid test                        NaN              NaN
# Strepto A                                      NaN              NaN
# Urine - Esterase                               NaN              NaN
# Urine - Aspect                                 NaN              NaN
# Urine - pH                                     NaN              NaN
# Urine - Hemoglobin                             NaN              NaN
# Urine - Bile pigments                          NaN              NaN
# Urine - Ketone Bodies                          NaN              NaN
# Urine - Nitrite                                NaN              NaN
# Urine - Urobilinogen                           NaN              NaN
# Urine - Protein                                NaN              NaN
# Urine - Leukocytes                             NaN              NaN
# Urine - Crystals                               NaN              NaN
# Urine - Hyaline cylinders                      NaN              NaN
# Urine - Granular cylinders                     NaN              NaN
# Urine - Yeasts                                 NaN              NaN
# Urine - Color                                  NaN              NaN
# SARS-Cov-2 exam result - Numerico                0                0
#
#                                               4165
# Patient ID                         b90320c6c7bbb1e
# SARS-Cov-2 exam result                    negative
# Respiratory Syncytial Virus                    NaN
# Influenza A                                    NaN
# Influenza B                                    NaN
# Parainfluenza 1                                NaN
# CoronavirusNL63                                NaN
# Rhinovirus/Enterovirus                         NaN
# Coronavirus HKU1                               NaN
# Parainfluenza 3                                NaN
# Chlamydophila pneumoniae                       NaN
# Adenovirus                                     NaN
# Parainfluenza 4                                NaN
# Coronavirus229E                                NaN
# CoronavirusOC43                                NaN
# Inf A H1N1 2009                                NaN
# Bordetella pertussis                           NaN
# Metapneumovirus                                NaN
# Parainfluenza 2                                NaN
# Influenza B, rapid test                        NaN
# Influenza A, rapid test                        NaN
# Strepto A                                      NaN
# Urine - Esterase                               NaN
# Urine - Aspect                                 NaN
# Urine - pH                                     NaN
# Urine - Hemoglobin                             NaN
# Urine - Bile pigments                          NaN
# Urine - Ketone Bodies                          NaN
# Urine - Nitrite                                NaN
# Urine - Urobilinogen                           NaN
# Urine - Protein                                NaN
# Urine - Leukocytes                             NaN
# Urine - Crystals                               NaN
# Urine - Hyaline cylinders                      NaN
# Urine - Granular cylinders                     NaN
# Urine - Yeasts                                 NaN
# Urine - Color                                  NaN
# SARS-Cov-2 exam result - Numerico                0

# %%
dp.breveDescricao(df_categoricas)
# Out:
# O data set possui:
# - 38 atributos/campos; e
# - 5644 registros.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5644 entries, 0 to 5643
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Patient ID                         5644 non-null   object
#  1   SARS-Cov-2 exam result             5644 non-null   object
#  2   Respiratory Syncytial Virus        1354 non-null   object
#  3   Influenza A                        1354 non-null   object
#  4   Influenza B                        1354 non-null   object
#  5   Parainfluenza 1                    1352 non-null   object
#  6   CoronavirusNL63                    1352 non-null   object
#  7   Rhinovirus/Enterovirus             1352 non-null   object
#  8   Coronavirus HKU1                   1352 non-null   object
#  9   Parainfluenza 3                    1352 non-null   object
#  10  Chlamydophila pneumoniae           1352 non-null   object
#  11  Adenovirus                         1352 non-null   object
#  12  Parainfluenza 4                    1352 non-null   object
#  13  Coronavirus229E                    1352 non-null   object
#  14  CoronavirusOC43                    1352 non-null   object
#  15  Inf A H1N1 2009                    1352 non-null   object
#  16  Bordetella pertussis               1352 non-null   object
#  17  Metapneumovirus                    1352 non-null   object
#  18  Parainfluenza 2                    1352 non-null   object
#  19  Influenza B, rapid test            820 non-null    object
#  20  Influenza A, rapid test            820 non-null    object
#  21  Strepto A                          332 non-null    object
#  22  Urine - Esterase                   60 non-null     object
#  23  Urine - Aspect                     70 non-null     object
#  24  Urine - pH                         70 non-null     object
#  25  Urine - Hemoglobin                 70 non-null     object
#  26  Urine - Bile pigments              70 non-null     object
#  27  Urine - Ketone Bodies              57 non-null     object
#  28  Urine - Nitrite                    1 non-null      object
#  29  Urine - Urobilinogen               69 non-null     object
#  30  Urine - Protein                    60 non-null     object
#  31  Urine - Leukocytes                 70 non-null     object
#  32  Urine - Crystals                   70 non-null     object
#  33  Urine - Hyaline cylinders          67 non-null     object
#  34  Urine - Granular cylinders         69 non-null     object
#  35  Urine - Yeasts                     70 non-null     object
#  36  Urine - Color                      70 non-null     object
#  37  SARS-Cov-2 exam result - Numerico  5644 non-null   int32
# dtypes: int32(1), object(37)
# memory usage: 1.6+ MB
# G:\Meu Drive\02. Courses\1. Em andamento\Udemy - Machine Learning e Data Science com Python de A à Z\Alterações-Gustavo\data_prep.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis=1, how="all", inplace=True)

# %%
df_temp = dp.cardinalidade(df_categoricas)
df_temp[df_temp.Cardinalidade<=3]
# Out:
#                              Atributo  Cardinalidade  \
# 30  SARS-Cov-2 exam result - Numerico              2
# 28                     Urine - Yeasts              2
# 27         Urine - Granular cylinders              2
# 26          Urine - Hyaline cylinders              2
# 16                    Parainfluenza 2              2
# 23               Urine - Urobilinogen              3
# 18            Influenza A, rapid test              3
# 17            Influenza B, rapid test              3
# 14               Bordetella pertussis              3
# 13                    Inf A H1N1 2009              3
# 12                    CoronavirusOC43              3
# 0         Respiratory Syncytial Virus              3
# 10                    Parainfluenza 4              3
# 1                         Influenza A              3
# 2                         Influenza B              3
# 3                     Parainfluenza 1              3
# 4                     CoronavirusNL63              3
# 11                    Coronavirus229E              3
# 15                    Metapneumovirus              3
# 6                    Coronavirus HKU1              3
# 7                     Parainfluenza 3              3
# 8            Chlamydophila pneumoniae              3
# 9                          Adenovirus              3
# 5              Rhinovirus/Enterovirus              3
#
#                           Valores
# 30                         [0, 1]
# 28                  [nan, absent]
# 27                  [nan, absent]
# 26                  [nan, absent]
# 16            [nan, not_detected]
# 23        [nan, normal, not_done]
# 18      [nan, negative, positive]
# 17      [nan, negative, positive]
# 14  [nan, not_detected, detected]
# 13  [nan, not_detected, detected]
# 12  [nan, not_detected, detected]
# 0   [nan, not_detected, detected]
# 10  [nan, not_detected, detected]
# 1   [nan, not_detected, detected]
# 2   [nan, not_detected, detected]
# 3   [nan, not_detected, detected]
# 4   [nan, not_detected, detected]
# 11  [nan, not_detected, detected]
# 15  [nan, not_detected, detected]
# 6   [nan, not_detected, detected]
# 7   [nan, not_detected, detected]
# 8   [nan, not_detected, detected]
# 9   [nan, not_detected, detected]
# 5   [nan, detected, not_detected]

# %% [markdown]
# #### Excluindo atributos mais "grosseiros":
# - Atibuto **Patient ID:** Pois é a identificação do paciente.
# - Atibuto **Urine - Nitrite:** Pois só há um valor não nulo, portanto, não deve adicionar
# - Atibuto **SARS-Cov-2 exam result:** Pois já fizemos o Label encoding deste atributo.
# - Atibuto **Urine - Protein	3:** Pois os três valores não parecem adicionar valor a análise (nan, absent, not_done).
# - Atibuto **Urine - Ketone Bodies:** Pois os três valores não parecem adicionar valor a análise (nan, absent, not_done).
# - Atibuto **Urine - Bile pigments:** Pois os três valores não parecem adicionar valor a análise (nan, absent, not_done).
# - Atibuto **Urine - Esterase:** Pois os três valores não parecem adicionar valor a análise (nan, absent, not_done).

# %%
df_categoricas.drop(["Patient ID"
                     , "Urine - Nitrite"
                     , "SARS-Cov-2 exam result"
                     , "Urine - Protein"
                     , "Urine - Ketone Bodies"
                     , "Urine - Bile pigments"
                     , "Urine - Esterase"
                    ], axis=1, inplace=True)
# Out:
# C:\Users\gusta\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# #### Excluindo atributos de baixa cardinalidade com valores nan e absent
# À primeira vista, *nan* e *absent* parecem-me não adicionar valor às análises. Removerei os quatro atributos:
# - 'Urine - Yeasts',
# - 'Urine - Granular cylinders'
# - 'Urine - Hyaline cylinders',
# - 'Parainfluenza 2'

# %%
df_categoricas.drop(['Urine - Yeasts'
                     , 'Urine - Granular cylinders'
                     , 'Urine - Hyaline cylinders'
                     , 'Parainfluenza 2']
                    , axis=1, inplace=True)
# Out:
# C:\Users\gusta\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
dp.cardinalidade(df_categoricas)
# Out:
#                              Atributo  Cardinalidade  \
# 26  SARS-Cov-2 exam result - Numerico              2
# 22               Urine - Urobilinogen              3
# 17            Influenza A, rapid test              3
# 16            Influenza B, rapid test              3
# 15                    Metapneumovirus              3
# 14               Bordetella pertussis              3
# 12                    CoronavirusOC43              3
# 11                    Coronavirus229E              3
# 10                    Parainfluenza 4              3
# 0         Respiratory Syncytial Virus              3
# 8            Chlamydophila pneumoniae              3
# 1                         Influenza A              3
# 9                          Adenovirus              3
# 2                         Influenza B              3
# 3                     Parainfluenza 1              3
# 13                    Inf A H1N1 2009              3
# 5              Rhinovirus/Enterovirus              3
# 6                    Coronavirus HKU1              3
# 7                     Parainfluenza 3              3
# 4                     CoronavirusNL63              3
# 21                 Urine - Hemoglobin              4
# 18                          Strepto A              4
# 25                      Urine - Color              5
# 19                     Urine - Aspect              5
# 24                   Urine - Crystals              6
# 20                         Urine - pH             16
# 23                 Urine - Leukocytes             32
#
#                                                                                                                                                                                                                       Valores
# 26                                                                                                                                                                                                                     [0, 1]
# 22                                                                                                                                                                                                    [nan, normal, not_done]
# 17                                                                                                                                                                                                  [nan, negative, positive]
# 16                                                                                                                                                                                                  [nan, negative, positive]
# 15                                                                                                                                                                                              [nan, not_detected, detected]
# 14                                                                                                                                                                                              [nan, not_detected, detected]
# 12                                                                                                                                                                                              [nan, not_detected, detected]
# 11                                                                                                                                                                                              [nan, not_detected, detected]
# 10                                                                                                                                                                                              [nan, not_detected, detected]
# 0                                                                                                                                                                                               [nan, not_detected, detected]
# 8                                                                                                                                                                                               [nan, not_detected, detected]
# 1                                                                                                                                                                                               [nan, not_detected, detected]
# 9                                                                                                                                                                                               [nan, not_detected, detected]
# 2                                                                                                                                                                                               [nan, not_detected, detected]
# 3                                                                                                                                                                                               [nan, not_detected, detected]
# 13                                                                                                                                                                                              [nan, not_detected, detected]
# 5                                                                                                                                                                                               [nan, detected, not_detected]
# 6                                                                                                                                                                                               [nan, not_detected, detected]
# 7                                                                                                                                                                                               [nan, not_detected, detected]
# 4                                                                                                                                                                                               [nan, not_detected, detected]
# 21                                                                                                                                                                                           [nan, absent, present, not_done]
# 18                                                                                                                                                                                        [nan, positive, negative, not_done]
# 25                                                                                                                                                                         [nan, light_yellow, yellow, orange, citrus_yellow]
# 19                                                                                                                                                                     [nan, clear, cloudy, altered_coloring, lightly_cloudy]
# 24                                                                                                                          [nan, Ausentes, Urato Amorfo --+, Oxalato de Cálcio +++, Oxalato de Cálcio -++, Urato Amorfo +++]
# 20                                                                                                                                           [nan, 6.5, 6.0, Não Realizado, 5.0, 7.0, 5, 5.5, 7.5, 6, 8.0, 6, 6.5, 7, 5, 5.5]
# 23  [nan, 38000, 5942000, 32000, 22000, <1000, 3000, 16000, 7000, 5300, 1000, 4000, 5000, 10600, 6000, 2500, 2600, 23000, 124000, 8000, 29000, 2000, 624000, 40000, 3310000, 229000, 19000, 28000, 10000, 4600, 77000, 43000]

# %%
dp.serieNulos(df_categoricas, 95)
# Out:
# (Urine - Urobilinogen    98.777463
#  Urine - Color           98.759745
#  Urine - Crystals        98.759745
#  Urine - Leukocytes      98.759745
#  Urine - Hemoglobin      98.759745
#  Urine - pH              98.759745
#  Urine - Aspect          98.759745
#  dtype: float64,
#  '-> 7 atributos/features/campos possuem mais de 95% de valores nulos.')
