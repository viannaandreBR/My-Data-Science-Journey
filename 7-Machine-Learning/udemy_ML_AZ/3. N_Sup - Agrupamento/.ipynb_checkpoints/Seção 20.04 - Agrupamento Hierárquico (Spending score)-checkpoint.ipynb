# %% [markdown]
# # Seção 20.03 - Agrupamento com K-means e K-medians (Spending score)
# Para esta seção, usarei a base de dados "Mall_Customers.csv" disponibilizada no curso Machine Learning A-Z™: Hands-On Python & R In Data Science.

# %%
# Instruções basiconas de sempre.

# Lidar com dataframes.
import numpy as np
import pandas as pd

# Lidar com gráficos.
import matplotlib.pyplot as plt
import seaborn as sns

# Lidar com preparação de dados.
# from data_prep import data_prep as dp # Eu que fiz esse modulinho ("uuuuuuuuuma bosts!").
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# Lidar com validação de modelos.
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
nomeDaBase = "../../bases/Mall_Customers.csv"
df = pd.read_csv(nomeDaBase, sep=",", encoding="utf-8", index_col=0)

df.head(10).T
# Out:
# CustomerID                 1     2       3       4       5       6       7  \
# Genre                   Male  Male  Female  Female  Female  Female  Female
# Age                     19    21    20      23      31      22      35
# Annual Income (k$)      15    15    16      16      17      17      18
# Spending Score (1-100)  39    81    6       77      40      76      6
#
# CustomerID                   8     9      10
# Genre                   Female  Male  Female
# Age                     23      64    30
# Annual Income (k$)      18      19    19
# Spending Score (1-100)  94      3     72

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
# Genre                     200 non-null object
# Age                       200 non-null int64
# Annual Income (k$)        200 non-null int64
# Spending Score (1-100)    200 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 7.0+ KB

# %%
atributos_int = df.select_dtypes(include=["int"]).columns

for atributos in atributos_int:
    df[atributos] = df[atributos].astype(float)
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
# Genre                     200 non-null object
# Age                       200 non-null float64
# Annual Income (k$)        200 non-null float64
# Spending Score (1-100)    200 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 15.0+ KB

# %%
df.describe().T
# Out:
#                         count   mean        std   min    25%   50%   75%  \
# Age                     200.0  38.85  13.969007  18.0  28.75  36.0  49.0
# Annual Income (k$)      200.0  60.56  26.264721  15.0  41.50  61.5  78.0
# Spending Score (1-100)  200.0  50.20  25.823522  1.0   34.75  50.0  73.0
#
#                           max
# Age                     70.0
# Annual Income (k$)      137.0
# Spending Score (1-100)  99.0

# %%
sns.set(style="darkgrid")

sns.pairplot(df[["Annual Income (k$)","Spending Score (1-100)", "Genre"]]
             , kind="scatter"
             , hue="Genre"
             , markers=["o", "s"]
             , palette="Set2")
plt.show();

# %% [markdown]
# ### Análise preliminar da base:
# Nenhuma incosistêcia ou erros foram encontrados.

# %% [markdown]
# # Procurando o número de clusters

# %%
# Separando os fatores/previsores da resposta/target:
    
x = df.iloc[:, 2:]
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.cluster import KMeans

# Quantidade de clusters que serão testados
k = list(range(1, 15))

# Armazena das inércias para cada k
inercia = []

# Roda o K-means para cada k fornecido
for i in k:
    classificador = KMeans(n_clusters=i
                          , init="k-means++"
                          , max_iter=200
                          , n_init=10
                          , random_state=0)
    classificador.fit(x)
    inercia.append(classificador.inertia_)

# Plota o gráfico com as inércias
plt.plot(k, inercia, '-o')
plt.title("Estimativa do número de clusters")
plt.xlabel('Número de clusters')
plt.ylabel('Inércia')
plt.show()

# %% [markdown]
# ### 2.1) Simplesmente aplicando o K-means com split test e depois validação cruzada

# %%
classificador = KMeans(n_clusters=5
                       , init="k-means++"
                       , max_iter=200
                       , n_init=10
                       , random_state=0)
classificador.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=200,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %% [markdown]
# ### Plotando o gráfico

# %%
# salva os centroides
centroides = classificador.cluster_centers_
# salva as labels dos clusters para cada exemplo
y_kmeans = classificador.predict(x)

# %%
plt.rcParams['figure.figsize'] = (12, 7)

# plota os dados identificando seus clusters
plt.scatter(df["Annual Income (k$)"], df["Spending Score (1-100)"], c = y_kmeans, alpha = 0.5, cmap = 'rainbow')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
# plota os centroides também
plt.scatter(centroides[:, 0], centroides[:, 1], c='black', marker='X', s=300, alpha=0.5)
plt.show()
