# %% [markdown]
# # Seção 04.03 - Aprendizagem Bayesiana (base censo)
# Para esta seção, usarei a base de dados "census.csv" disponibilizada no curso do Professor Jones na UDEMY.

# %%
# Instruções basiconas de sempre.

# Lidar com dataframes.
import numpy as np
import pandas as pd

# Lidar com gráficos.
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from plotting import (multiple_histograms_plot,
                      bar_plot_with_categorical,
                      plot_confusion_matrix,
                      plot_confusion_matrix_2,
                      plot_roc)

# Lidar com preparação de dados.
from data_prep import data_prep as dp # Eu que fiz esse modulinho ("uuuuuuuuuma bosts!").
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import (train_test_split
                                     , cross_val_score
                                     , StratifiedKFold)

# Lidar com validação de modelos.
from sklearn.metrics import (confusion_matrix
                             , accuracy_score
                             , classification_report)

pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
nomeDaBase = "../bases/census.csv"
df = pd.read_csv(nomeDaBase, sep=",", encoding="utf-8")

# %%
df.head(7).T
# Out:
#                              0                    1                   2  \
# age             39              50                   38
# workclass        State-gov       Self-emp-not-inc     Private
# final-weight    77516           83311                215646
# education        Bachelors       Bachelors            HS-grad
# education-num   13              13                   9
# marital-status   Never-married   Married-civ-spouse   Divorced
# occupation       Adm-clerical    Exec-managerial      Handlers-cleaners
# relationship     Not-in-family   Husband              Not-in-family
# race             White           White                White
# sex              Male            Male                 Male
# capital-gain    2174            0                    0
# capital-loos    0               0                    0
# hour-per-week   40              13                   40
# native-country   United-States   United-States        United-States
# income           <=50K           <=50K                <=50K
#
#                                   3                    4                    5  \
# age             53                   28                   37
# workclass        Private              Private              Private
# final-weight    234721               338409               284582
# education        11th                 Bachelors            Masters
# education-num   7                    13                   14
# marital-status   Married-civ-spouse   Married-civ-spouse   Married-civ-spouse
# occupation       Handlers-cleaners    Prof-specialty       Exec-managerial
# relationship     Husband              Wife                 Wife
# race             Black                Black                White
# sex              Male                 Female               Female
# capital-gain    0                    0                    0
# capital-loos    0                    0                    0
# hour-per-week   40                   40                   40
# native-country   United-States        Cuba                 United-States
# income           <=50K                <=50K                <=50K
#
#                                      6
# age             49
# workclass        Private
# final-weight    160187
# education        9th
# education-num   5
# marital-status   Married-spouse-absent
# occupation       Other-service
# relationship     Not-in-family
# race             Black
# sex              Female
# capital-gain    0
# capital-loos    0
# hour-per-week   16
# native-country   Jamaica
# income           <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# final-weight      32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loos      32561 non-null int64
# hour-per-week     32561 non-null int64
# native-country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe().T
# Out:
#                  count           mean            std      min       25%  \
# age            32561.0  38.581647      13.640433      17.0     28.0
# final-weight   32561.0  189778.366512  105549.977697  12285.0  117827.0
# education-num  32561.0  10.080679      2.572720       1.0      9.0
# capital-gain   32561.0  1077.648844    7385.292085    0.0      0.0
# capital-loos   32561.0  87.303830      402.960219     0.0      0.0
# hour-per-week  32561.0  40.437456      12.347429      1.0      40.0
#
#                     50%       75%        max
# age            37.0      48.0      90.0
# final-weight   178356.0  237051.0  1484705.0
# education-num  10.0      12.0      16.0
# capital-gain   0.0       0.0       99999.0
# capital-loos   0.0       0.0       4356.0
# hour-per-week  40.0      45.0      99.0

# %%
dp.cardinalidade(df_tratado)
# Out:
#          Atributo  Cardinalidade  \
# 6  sex             2
# 8  income          2
# 5  race            5
# 4  relationship    6
# 2  marital-status  7
# 0  workclass       9
# 3  occupation      15
# 1  education       16
# 7  native-country  42
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Valores
# 6  [ Male,  Female]
# 8  [ <=50K,  >50K]
# 5  [ White,  Black,  Asian-Pac-Islander,  Amer-Indian-Eskimo,  Other]
# 4  [ Not-in-family,  Husband,  Wife,  Own-child,  Unmarried,  Other-relative]
# 2  [ Never-married,  Married-civ-spouse,  Divorced,  Married-spouse-absent,  Separated,  Married-AF-spouse,  Widowed]
# 0  [ State-gov,  Self-emp-not-inc,  Private,  Federal-gov,  Local-gov,  ?,  Self-emp-inc,  Without-pay,  Never-worked]
# 3  [ Adm-clerical,  Exec-managerial,  Handlers-cleaners,  Prof-specialty,  Other-service,  Sales,  Craft-repair,  Transport-moving,  Farming-fishing,  Machine-op-inspct,  Tech-support,  ?,  Protective-serv,  Armed-Forces,  Priv-house-serv]
# 1  [ Bachelors,  HS-grad,  11th,  Masters,  9th,  Some-college,  Assoc-acdm,  Assoc-voc,  7th-8th,  Doctorate,  Prof-school,  5th-6th,  10th,  1st-4th,  Preschool,  12th]
# 7  [ United-States,  Cuba,  Jamaica,  India,  ?,  Mexico,  South,  Puerto-Rico,  Honduras,  England,  Canada,  Germany,  Iran,  Philippines,  Italy,  Poland,  Columbia,  Cambodia,  Thailand,  Ecuador,  Laos,  Taiwan,  Haiti,  Portugal,  Dominican-Republic,  El-Salvador,  France,  Guatemala,  China,  Japan,  Yugoslavia,  Peru,  Outlying-US(Guam-USVI-etc),  Scotland,  Trinadad&Tobago,  Greece,  Nicaragua,  Vietnam,  Hong,  Ireland,  Hungary,  Holand-Netherlands]

# %%
df_obj = df.select_dtypes(exclude=["int64", "float64"])

df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

for atributo in df_obj.columns:
    if "?" in df[atributo].values:
        print(f"""O Atributo "{atributo}" tem {len(df[df[atributo]=="?"])} valores iguais a "?".""")
#     df_tratado[i].replace('?', np.nan, inplace=True)
# Out:
# O Atributo "workclass" tem 1836 valores iguais a "?".
# O Atributo "occupation" tem 1843 valores iguais a "?".
# O Atributo "native-country" tem 583 valores iguais a "?".

# %% [markdown]
# ## Análise preliminar dos dados:
#
# - Trata-se de uma base com 32561 registros, 14 atributos (sendo 6 nupericos e 8 categóricos) e 1 atributo alvo.
# - À primeira vista, não há dados faltantes, porém, na análise da cardinalidade vemos um "?", e este símbolo foi considerado como valor faltante.
# -
#
# ### Próxima etapa:
# 1. Tratar os valores indicados como "?". **Alternativas de tratamento possíveis:**
#
#
# > a. Deixar quieto e encarar o "?" como um valor válido;
#
# > b. Remoção dos registros com "?";
#
# > c. Usar a moda de cada atributo para substituir o "?"; ou
#
# > d. Usar KNN para determinar qual o valor mais provável para o valor faltante.

# %% [markdown]
# #### a. Deixar quieto e encarar o "?" como um valor válido

# %%
# Copiando df original para um novo df (df_tratado).

df_tratado = df.copy()

state_dummies = pd.get_dummies(df_tratado[df_obj.columns], drop_first=True)

df_tratado.drop(df_obj.columns, axis=1, inplace=True)

df_tratado = pd.concat([df_tratado, state_dummies], axis=1)

# %%
df_tratado.head(7).T
# Out:
#                                                0      1       2       3  \
# age                                        39     50     38      53
# final-weight                               77516  83311  215646  234721
# education-num                              13     13     9       7
# capital-gain                               2174   0      0       0
# capital-loos                               0      0      0       0
# hour-per-week                              40     13     40      40
# workclass_Federal-gov                      0      0      0       0
# workclass_Local-gov                        0      0      0       0
# workclass_Never-worked                     0      0      0       0
# workclass_Private                          0      0      1       1
# workclass_Self-emp-inc                     0      0      0       0
# workclass_Self-emp-not-inc                 0      1      0       0
# workclass_State-gov                        1      0      0       0
# workclass_Without-pay                      0      0      0       0
# education_11th                             0      0      0       1
# education_12th                             0      0      0       0
# education_1st-4th                          0      0      0       0
# education_5th-6th                          0      0      0       0
# education_7th-8th                          0      0      0       0
# education_9th                              0      0      0       0
# education_Assoc-acdm                       0      0      0       0
# education_Assoc-voc                        0      0      0       0
# education_Bachelors                        1      1      0       0
# education_Doctorate                        0      0      0       0
# education_HS-grad                          0      0      1       0
# education_Masters                          0      0      0       0
# education_Preschool                        0      0      0       0
# education_Prof-school                      0      0      0       0
# education_Some-college                     0      0      0       0
# marital-status_Married-AF-spouse           0      0      0       0
# marital-status_Married-civ-spouse          0      1      0       1
# marital-status_Married-spouse-absent       0      0      0       0
# marital-status_Never-married               1      0      0       0
# marital-status_Separated                   0      0      0       0
# marital-status_Widowed                     0      0      0       0
# occupation_Adm-clerical                    1      0      0       0
# occupation_Armed-Forces                    0      0      0       0
# occupation_Craft-repair                    0      0      0       0
# occupation_Exec-managerial                 0      1      0       0
# occupation_Farming-fishing                 0      0      0       0
# occupation_Handlers-cleaners               0      0      1       1
# occupation_Machine-op-inspct               0      0      0       0
# occupation_Other-service                   0      0      0       0
# occupation_Priv-house-serv                 0      0      0       0
# occupation_Prof-specialty                  0      0      0       0
# occupation_Protective-serv                 0      0      0       0
# occupation_Sales                           0      0      0       0
# occupation_Tech-support                    0      0      0       0
# occupation_Transport-moving                0      0      0       0
# relationship_Not-in-family                 1      0      1       0
# relationship_Other-relative                0      0      0       0
# relationship_Own-child                     0      0      0       0
# relationship_Unmarried                     0      0      0       0
# relationship_Wife                          0      0      0       0
# race_Asian-Pac-Islander                    0      0      0       0
# race_Black                                 0      0      0       1
# race_Other                                 0      0      0       0
# race_White                                 1      1      1       0
# sex_Male                                   1      1      1       1
# native-country_Cambodia                    0      0      0       0
# native-country_Canada                      0      0      0       0
# native-country_China                       0      0      0       0
# native-country_Columbia                    0      0      0       0
# native-country_Cuba                        0      0      0       0
# native-country_Dominican-Republic          0      0      0       0
# native-country_Ecuador                     0      0      0       0
# native-country_El-Salvador                 0      0      0       0
# native-country_England                     0      0      0       0
# native-country_France                      0      0      0       0
# native-country_Germany                     0      0      0       0
# native-country_Greece                      0      0      0       0
# native-country_Guatemala                   0      0      0       0
# native-country_Haiti                       0      0      0       0
# native-country_Holand-Netherlands          0      0      0       0
# native-country_Honduras                    0      0      0       0
# native-country_Hong                        0      0      0       0
# native-country_Hungary                     0      0      0       0
# native-country_India                       0      0      0       0
# native-country_Iran                        0      0      0       0
# native-country_Ireland                     0      0      0       0
# native-country_Italy                       0      0      0       0
# native-country_Jamaica                     0      0      0       0
# native-country_Japan                       0      0      0       0
# native-country_Laos                        0      0      0       0
# native-country_Mexico                      0      0      0       0
# native-country_Nicaragua                   0      0      0       0
# native-country_Outlying-US(Guam-USVI-etc)  0      0      0       0
# native-country_Peru                        0      0      0       0
# native-country_Philippines                 0      0      0       0
# native-country_Poland                      0      0      0       0
# native-country_Portugal                    0      0      0       0
# native-country_Puerto-Rico                 0      0      0       0
# native-country_Scotland                    0      0      0       0
# native-country_South                       0      0      0       0
# native-country_Taiwan                      0      0      0       0
# native-country_Thailand                    0      0      0       0
# native-country_Trinadad&Tobago             0      0      0       0
# native-country_United-States               1      1      1       1
# native-country_Vietnam                     0      0      0       0
# native-country_Yugoslavia                  0      0      0       0
# income_>50K                                0      0      0       0
#
#                                                 4       5       6
# age                                        28      37      49
# final-weight                               338409  284582  160187
# education-num                              13      14      5
# capital-gain                               0       0       0
# capital-loos                               0       0       0
# hour-per-week                              40      40      16
# workclass_Federal-gov                      0       0       0
# workclass_Local-gov                        0       0       0
# workclass_Never-worked                     0       0       0
# workclass_Private                          1       1       1
# workclass_Self-emp-inc                     0       0       0
# workclass_Self-emp-not-inc                 0       0       0
# workclass_State-gov                        0       0       0
# workclass_Without-pay                      0       0       0
# education_11th                             0       0       0
# education_12th                             0       0       0
# education_1st-4th                          0       0       0
# education_5th-6th                          0       0       0
# education_7th-8th                          0       0       0
# education_9th                              0       0       1
# education_Assoc-acdm                       0       0       0
# education_Assoc-voc                        0       0       0
# education_Bachelors                        1       0       0
# education_Doctorate                        0       0       0
# education_HS-grad                          0       0       0
# education_Masters                          0       1       0
# education_Preschool                        0       0       0
# education_Prof-school                      0       0       0
# education_Some-college                     0       0       0
# marital-status_Married-AF-spouse           0       0       0
# marital-status_Married-civ-spouse          1       1       0
# marital-status_Married-spouse-absent       0       0       1
# marital-status_Never-married               0       0       0
# marital-status_Separated                   0       0       0
# marital-status_Widowed                     0       0       0
# occupation_Adm-clerical                    0       0       0
# occupation_Armed-Forces                    0       0       0
# occupation_Craft-repair                    0       0       0
# occupation_Exec-managerial                 0       1       0
# occupation_Farming-fishing                 0       0       0
# occupation_Handlers-cleaners               0       0       0
# occupation_Machine-op-inspct               0       0       0
# occupation_Other-service                   0       0       1
# occupation_Priv-house-serv                 0       0       0
# occupation_Prof-specialty                  1       0       0
# occupation_Protective-serv                 0       0       0
# occupation_Sales                           0       0       0
# occupation_Tech-support                    0       0       0
# occupation_Transport-moving                0       0       0
# relationship_Not-in-family                 0       0       1
# relationship_Other-relative                0       0       0
# relationship_Own-child                     0       0       0
# relationship_Unmarried                     0       0       0
# relationship_Wife                          1       1       0
# race_Asian-Pac-Islander                    0       0       0
# race_Black                                 1       0       1
# race_Other                                 0       0       0
# race_White                                 0       1       0
# sex_Male                                   0       0       0
# native-country_Cambodia                    0       0       0
# native-country_Canada                      0       0       0
# native-country_China                       0       0       0
# native-country_Columbia                    0       0       0
# native-country_Cuba                        1       0       0
# native-country_Dominican-Republic          0       0       0
# native-country_Ecuador                     0       0       0
# native-country_El-Salvador                 0       0       0
# native-country_England                     0       0       0
# native-country_France                      0       0       0
# native-country_Germany                     0       0       0
# native-country_Greece                      0       0       0
# native-country_Guatemala                   0       0       0
# native-country_Haiti                       0       0       0
# native-country_Holand-Netherlands          0       0       0
# native-country_Honduras                    0       0       0
# native-country_Hong                        0       0       0
# native-country_Hungary                     0       0       0
# native-country_India                       0       0       0
# native-country_Iran                        0       0       0
# native-country_Ireland                     0       0       0
# native-country_Italy                       0       0       0
# native-country_Jamaica                     0       0       1
# native-country_Japan                       0       0       0
# native-country_Laos                        0       0       0
# native-country_Mexico                      0       0       0
# native-country_Nicaragua                   0       0       0
# native-country_Outlying-US(Guam-USVI-etc)  0       0       0
# native-country_Peru                        0       0       0
# native-country_Philippines                 0       0       0
# native-country_Poland                      0       0       0
# native-country_Portugal                    0       0       0
# native-country_Puerto-Rico                 0       0       0
# native-country_Scotland                    0       0       0
# native-country_South                       0       0       0
# native-country_Taiwan                      0       0       0
# native-country_Thailand                    0       0       0
# native-country_Trinadad&Tobago             0       0       0
# native-country_United-States               0       1       0
# native-country_Vietnam                     0       0       0
# native-country_Yugoslavia                  0       0       0
# income_>50K                                0       0       0

# %% [markdown]
# ### Usando *train_test_split*

# %%
x = df_tratado.iloc[:, 0:-1]
y = df_tratado.iloc[:, -1]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %% [markdown]
# ### Aplicando o escalonamento

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning:
#
# Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning:
#
# Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning:
#
# Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.

# %% [markdown]
# ### Aplicando o modelo

# %%
from sklearn.naive_bayes import GaussianNB

classificador = GaussianNB()

classificador.fit(x_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred = classificador.predict(x_test)

# %% [markdown]
# ### Verificando como o modelo se saiu

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Métrica 1 (Acurácia): {:.4f}.".format(
    accuracy_score(y_test, y_pred, normalize=True, sample_weight=None)))
print("Métrica 2 (Relatório de classificação):\n{}.".format(
    classification_report(y_test, y_pred)))

plot_confusion_matrix_2(y_test, y_pred, normalize=True);
# Out:
# Métrica 1 (Acurácia): 0.4538.
# Métrica 2 (Relatório de classificação):
#               precision    recall  f1-score   support
#
#            0       0.97      0.29      0.44      6159
#            1       0.31      0.97      0.46      1982
#
#    micro avg       0.45      0.45      0.45      8141
#    macro avg       0.64      0.63      0.45      8141
# weighted avg       0.81      0.45      0.45      8141
# .
# Normalized confusion matrix
# [[0.2860854  0.7139146 ]
#  [0.02522704 0.97477296]]
