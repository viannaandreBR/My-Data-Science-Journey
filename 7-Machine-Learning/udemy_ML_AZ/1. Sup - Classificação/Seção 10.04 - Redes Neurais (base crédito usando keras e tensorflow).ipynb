# %% [markdown]
# # Seção 10.04 - Redes Neurais Artificiais (base crédito usando keras e tensorflow)
# Para esta seção, usarei a base de dados "credit-data.csv" disponibilizada no curso do Professor Jones na UDEMY.
#
# Motivação: Otimização da classificação usando redes neurais.

# %% [markdown]
# # Pontos importantes da regressão com redes neurais:
# 1. Teremos somente um neurônio na saída.
# 2. A função de ativação linear no neurônio de saída tem bons resultados.
# 3. A função de ativação RELU nos neurônios das camadas ocultas tem bons resultados.

# %%
# Instruções basiconas de sempre.

# Lidar com dataframes.
import numpy as np
import pandas as pd

# Lidar com gráficos.
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from plotting import (multiple_histograms_plot,
                      bar_plot_with_categorical,
                      plot_confusion_matrix,
                      plot_confusion_matrix_2,
                      plot_roc)

# Lidar com preparação de dados.
from data_prep import data_prep as dp # Eu que fiz esse modulinho ("uuuuuuuuuma bosts!").
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import (train_test_split
                                     , cross_val_score
                                     , StratifiedKFold)

# Lidar com validação de modelos.
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
nomeDaBase = "../bases/credit-data.csv"
df = pd.read_csv(nomeDaBase, sep=",", encoding="utf-8", index_col="clientid")

# %%
df.head().T
# Out:
# clientid             1             2             3             4             5
# income    66155.925095  34415.153966  57317.170063  42709.534201  66952.688845
# age       59.017015     48.117153     63.108049     45.751972     18.584336
# loan      8106.532131   6564.745018   8020.953296   6103.642260   8770.099235
# default   0.000000      0.000000      0.000000      0.000000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 1 to 2000
# Data columns (total 4 columns):
# income     2000 non-null float64
# age        1997 non-null float64
# loan       2000 non-null float64
# default    2000 non-null int64
# dtypes: float64(3), int64(1)
# memory usage: 78.1 KB

# %%
df.describe().T
# Out:
#           count          mean           std          min           25%  \
# income   2000.0  45331.600018  14326.327119  20014.48947  32796.459717
# age      1997.0  40.807559     13.624469    -52.42328     28.990415
# loan     2000.0  4444.369695   3045.410024   1.37763      1939.708847
# default  2000.0  0.141500      0.348624      0.00000      0.000000
#
#                   50%           75%           max
# income   45789.117313  57791.281668  69995.685578
# age      41.317159     52.587040     63.971796
# loan     3974.719419   6432.410625   13766.051239
# default  0.000000      0.000000      1.000000

# %% [markdown]
# ### Problemas encontrados na base:
# 1. Em "age", há 3 valores nulos e há a presença de valores negativos.
#
# #### OBSERVAÇÃO:
#
# No mundo real, os problemas com as bases são muito piores. Deve-se ter muita atenção pois os dados podem não representar a realidade do processo.

# %%
df.loc[df.age < 0, "age"] = df.age.mean()

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy="mean")
imputer.fit(df)
df_tratado = pd.DataFrame(data=imputer.transform(df), columns=df.columns)

# %% [markdown]
# ## 1) Aplicação da Aprendizagem por random forests
#
# ### 1.1) Usando *train_test_split*

# %%
# Separando os fatores/previsores da resposta/target:
    
x = df_tratado.iloc[:, 0:-1]
y = df_tratado.iloc[:, -1]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Escalonamento
# Nesse algoritmo é importante executar o escalonamento.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)

x_test = scaler.transform(x_test)

# %% [markdown]
# # Aplicando o modelo

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

classificador = Sequential()

classificador.add(Dense(units=2, activation="relu", input_dim=3)) # camada de entrada
classificador.add(Dense(units=2, activation="relu")) # camada oculta
classificador.add(Dense(units=1, activation="sigmoid")) # camada de saída

classificador.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

classificador.fit(x_train, y_train, batch_size=10, epochs=100)

y_pred = classificador.predict(x_test)
y_pred = np.where(y_pred > .6, 1, 0)
# Out:
# Epoch 1/100
# 1600/1600 [==============================] - 0s 227us/step - loss: 0.4806 - accuracy: 0.8556
# Epoch 2/100
# 1600/1600 [==============================] - 0s 149us/step - loss: 0.3844 - accuracy: 0.8556
# Epoch 3/100
# 1600/1600 [==============================] - 0s 145us/step - loss: 0.3240 - accuracy: 0.8556
# Epoch 4/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.2842 - accuracy: 0.8556
# Epoch 5/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.2547 - accuracy: 0.8556
# Epoch 6/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.2298 - accuracy: 0.8556
# Epoch 7/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.2067 - accuracy: 0.8556
# Epoch 8/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.1872 - accuracy: 0.8556
# Epoch 9/100
# 1600/1600 [==============================] - 0s 145us/step - loss: 0.1705 - accuracy: 0.8556
# Epoch 10/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.1574 - accuracy: 0.8906
# Epoch 11/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.1477 - accuracy: 0.9563
# Epoch 12/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.1392 - accuracy: 0.9631
# Epoch 13/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.1315 - accuracy: 0.9644
# Epoch 14/100
# 1600/1600 [==============================] - 0s 143us/step - loss: 0.1243 - accuracy: 0.9700
# Epoch 15/100
# 1600/1600 [==============================] - 0s 143us/step - loss: 0.1176 - accuracy: 0.9737
# Epoch 16/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.1112 - accuracy: 0.9737
# Epoch 17/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.1053 - accuracy: 0.9769
# Epoch 18/100
# 1600/1600 [==============================] - 0s 140us/step - loss: 0.1000 - accuracy: 0.9787
# Epoch 19/100
# 1600/1600 [==============================] - 0s 138us/step - loss: 0.0948 - accuracy: 0.9806
# Epoch 20/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.0899 - accuracy: 0.9819
# Epoch 21/100
# 1600/1600 [==============================] - 0s 139us/step - loss: 0.0853 - accuracy: 0.9837
# Epoch 22/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0812 - accuracy: 0.9837
# Epoch 23/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.0771 - accuracy: 0.9856
# Epoch 24/100
# 1600/1600 [==============================] - 0s 140us/step - loss: 0.0734 - accuracy: 0.9856
# Epoch 25/100
# 1600/1600 [==============================] - 0s 138us/step - loss: 0.0700 - accuracy: 0.9856
# Epoch 26/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.0666 - accuracy: 0.9869
# Epoch 27/100
# 1600/1600 [==============================] - 0s 152us/step - loss: 0.0635 - accuracy: 0.9894
# Epoch 28/100
# 1600/1600 [==============================] - 0s 140us/step - loss: 0.0606 - accuracy: 0.9881
# Epoch 29/100
# 1600/1600 [==============================] - 0s 143us/step - loss: 0.0580 - accuracy: 0.9894
# Epoch 30/100
# 1600/1600 [==============================] - 0s 156us/step - loss: 0.0554 - accuracy: 0.9906
# Epoch 31/100
# 1600/1600 [==============================] - 0s 143us/step - loss: 0.0531 - accuracy: 0.9944
# Epoch 32/100
# 1600/1600 [==============================] - 0s 138us/step - loss: 0.0508 - accuracy: 0.9944
# Epoch 33/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0486 - accuracy: 0.9937
# Epoch 34/100
# 1600/1600 [==============================] - 0s 138us/step - loss: 0.0467 - accuracy: 0.9950
# Epoch 35/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0447 - accuracy: 0.9950
# Epoch 36/100
# 1600/1600 [==============================] - 0s 138us/step - loss: 0.0429 - accuracy: 0.9944
# Epoch 37/100
# 1600/1600 [==============================] - 0s 136us/step - loss: 0.0412 - accuracy: 0.9956
# Epoch 38/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0396 - accuracy: 0.9956
# Epoch 39/100
# 1600/1600 [==============================] - 0s 137us/step - loss: 0.0381 - accuracy: 0.9956
# Epoch 40/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.0367 - accuracy: 0.9962
# Epoch 41/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.0353 - accuracy: 0.9956
# Epoch 42/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0338 - accuracy: 0.9975
# Epoch 43/100
# 1600/1600 [==============================] - 0s 139us/step - loss: 0.0328 - accuracy: 0.9987
# Epoch 44/100
# 1600/1600 [==============================] - 0s 143us/step - loss: 0.0315 - accuracy: 0.9987
# Epoch 45/100
# 1600/1600 [==============================] - 0s 152us/step - loss: 0.0304 - accuracy: 0.9969
# Epoch 46/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0294 - accuracy: 0.9987
# Epoch 47/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.0285 - accuracy: 0.9987
# Epoch 48/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.0274 - accuracy: 0.9981
# Epoch 49/100
# 1600/1600 [==============================] - 0s 139us/step - loss: 0.0266 - accuracy: 0.9994
# Epoch 50/100
# 1600/1600 [==============================] - 0s 143us/step - loss: 0.0256 - accuracy: 0.9981
# Epoch 51/100
# 1600/1600 [==============================] - 0s 140us/step - loss: 0.0248 - accuracy: 0.9987
# Epoch 52/100
# 1600/1600 [==============================] - 0s 140us/step - loss: 0.0241 - accuracy: 0.9987
# Epoch 53/100
# 1600/1600 [==============================] - 0s 148us/step - loss: 0.0233 - accuracy: 0.9987
# Epoch 54/100
# 1600/1600 [==============================] - 0s 132us/step - loss: 0.0224 - accuracy: 0.9994
# Epoch 55/100
# 1600/1600 [==============================] - 0s 145us/step - loss: 0.0218 - accuracy: 0.9987
# Epoch 56/100
# 1600/1600 [==============================] - 0s 140us/step - loss: 0.0211 - accuracy: 0.9994
# Epoch 57/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 58/100
# 1600/1600 [==============================] - 0s 139us/step - loss: 0.0199 - accuracy: 0.9994
# Epoch 59/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.0194 - accuracy: 0.9987
# Epoch 60/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.0188 - accuracy: 0.9994
# Epoch 61/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 62/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.0180 - accuracy: 0.9987
# Epoch 63/100
# 1600/1600 [==============================] - 0s 158us/step - loss: 0.0173 - accuracy: 0.9994
# Epoch 64/100
# 1600/1600 [==============================] - 0s 143us/step - loss: 0.0169 - accuracy: 0.9987
# Epoch 65/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0164 - accuracy: 0.9994
# Epoch 66/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.0160 - accuracy: 0.9994
# Epoch 67/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 68/100
# 1600/1600 [==============================] - 0s 160us/step - loss: 0.0151 - accuracy: 0.9994
# Epoch 69/100
# 1600/1600 [==============================] - 0s 147us/step - loss: 0.0147 - accuracy: 0.9994
# Epoch 70/100
# 1600/1600 [==============================] - 0s 165us/step - loss: 0.0142 - accuracy: 0.9994
# Epoch 71/100
# 1600/1600 [==============================] - 0s 140us/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 72/100
# 1600/1600 [==============================] - 0s 152us/step - loss: 0.0137 - accuracy: 0.9994
# Epoch 73/100
# 1600/1600 [==============================] - 0s 143us/step - loss: 0.0134 - accuracy: 0.9994
# Epoch 74/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0132 - accuracy: 0.9994
# Epoch 75/100
# 1600/1600 [==============================] - 0s 141us/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 76/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 77/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0122 - accuracy: 0.9994
# Epoch 78/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.0120 - accuracy: 0.9994
# Epoch 79/100
# 1600/1600 [==============================] - 0s 134us/step - loss: 0.0117 - accuracy: 0.9994
# Epoch 80/100
# 1600/1600 [==============================] - 0s 132us/step - loss: 0.0115 - accuracy: 0.9994
# Epoch 81/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0112 - accuracy: 0.9987
# Epoch 82/100
# 1600/1600 [==============================] - 0s 137us/step - loss: 0.0112 - accuracy: 0.9987
# Epoch 83/100
# 1600/1600 [==============================] - 0s 151us/step - loss: 0.0108 - accuracy: 0.9994
# Epoch 84/100
# 1600/1600 [==============================] - 0s 168us/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 85/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0103 - accuracy: 0.9994
# Epoch 86/100
# 1600/1600 [==============================] - 0s 136us/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 87/100
# 1600/1600 [==============================] - 0s 129us/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 88/100
# 1600/1600 [==============================] - 0s 136us/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 89/100
# 1600/1600 [==============================] - 0s 142us/step - loss: 0.0096 - accuracy: 0.9994
# Epoch 90/100
# 1600/1600 [==============================] - 0s 131us/step - loss: 0.0093 - accuracy: 0.9994
# Epoch 91/100
# 1600/1600 [==============================] - 0s 134us/step - loss: 0.0092 - accuracy: 0.9994
# Epoch 92/100
# 1600/1600 [==============================] - 0s 131us/step - loss: 0.0092 - accuracy: 0.9994
# Epoch 93/100
# 1600/1600 [==============================] - 0s 122us/step - loss: 0.0087 - accuracy: 0.9994
# Epoch 94/100
# 1600/1600 [==============================] - 0s 144us/step - loss: 0.0088 - accuracy: 0.9994
# Epoch 95/100
# 1600/1600 [==============================] - 0s 135us/step - loss: 0.0086 - accuracy: 0.9994
# Epoch 96/100
# 1600/1600 [==============================] - 0s 134us/step - loss: 0.0084 - accuracy: 0.9994
# Epoch 97/100
# 1600/1600 [==============================] - 0s 136us/step - loss: 0.0083 - accuracy: 0.9994
# Epoch 98/100
# 1600/1600 [==============================] - 0s 134us/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 99/100
# 1600/1600 [==============================] - 0s 133us/step - loss: 0.0077 - accuracy: 0.9994
# Epoch 100/100
# 1600/1600 [==============================] - 0s 131us/step - loss: 0.0078 - accuracy: 0.9994

# %% [markdown]
# ### Verificando o como o modelo se saiu

# %%
from sklearn.metrics import (accuracy_score
                             , classification_report
                             , confusion_matrix)

print("Métrica 1 (Acurácia): {:.6}.".format(
    accuracy_score(y_test, y_pred, normalize=True, sample_weight=None)))
print("Métrica 2 (Relatório de classificação):\n{}.".format(
    classification_report(y_test, y_pred)))

plot_confusion_matrix_2(y_test, y_pred, normalize=True);
# Out:
# Métrica 1 (Acurácia): 0.9975.
# Métrica 2 (Relatório de classificação):
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       348
#          1.0       0.98      1.00      0.99        52
#
#    micro avg       1.00      1.00      1.00       400
#    macro avg       0.99      1.00      0.99       400
# weighted avg       1.00      1.00      1.00       400
# .
# Normalized confusion matrix
# [[0.99712644 0.00287356]
#  [0.         1.        ]]
